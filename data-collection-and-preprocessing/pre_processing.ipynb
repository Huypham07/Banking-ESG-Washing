# %% [markdown]
# # Data Collection and Pre-processing

# %% [markdown]
# - Input: Raw OCR Annual Report
# - Output: Sentence segmentation, Word segmentation
#
# 1. **Trích xuất và Phân đoạn**: Đọc văn bản từ file, phân tách thành câu
# 2. **Tách từ tiếng Việt**: Sử dụng VnCoreNLP để tách từ
# 3. **Làm sạch và Chuẩn hóa**: Chuyển chữ thường, loại bỏ noise, xóa stopwords

# %%
pip install underthesea vncorenlp
# Out:
# Collecting underthesea
#   Downloading underthesea-8.3.0-py3-none-any.whl.metadata (14 kB)
# Collecting vncorenlp
#   Downloading vncorenlp-1.0.3.tar.gz (2.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 29.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Click>=6.0 in /usr/local/lib/python3.12/dist-packages (from underthesea) (8.3.0)
# Collecting python-crfsuite>=0.9.6 (from underthesea)
#   Downloading python_crfsuite-0.9.11-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.3 kB)
# Requirement already satisfied: nltk>=3.8 in /usr/local/lib/python3.12/dist-packages (from underthesea) (3.9.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from underthesea) (4.67.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from underthesea) (2.32.4)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from underthesea) (1.5.2)
# Requirement already satisfied: scikit-learn>=1.6.1 in /usr/local/lib/python3.12/dist-packages (from underthesea) (1.6.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from underthesea) (6.0.3)
# Collecting underthesea_core==1.0.5 (from underthesea)
#   Downloading underthesea_core-1.0.5-cp312-cp312-manylinux2010_x86_64.whl.metadata (1.4 kB)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.12/dist-packages (from underthesea) (0.36.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk>=3.8->underthesea) (2024.11.6)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.6.1->underthesea) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.6.1->underthesea) (1.16.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.6.1->underthesea) (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->underthesea) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->underthesea) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->underthesea) (25.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->underthesea) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->underthesea) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->underthesea) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->underthesea) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->underthesea) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->underthesea) (2025.10.5)
# Downloading underthesea-8.3.0-py3-none-any.whl (8.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 89.6 MB/s eta 0:00:00
# Downloading underthesea_core-1.0.5-cp312-cp312-manylinux2010_x86_64.whl (978 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 978.4/978.4 kB 47.2 MB/s eta 0:00:00
# Downloading python_crfsuite-0.9.11-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 59.0 MB/s eta 0:00:00
# Building wheels for collected packages: vncorenlp
#   Building wheel for vncorenlp (setup.py) ... done
#   Created wheel for vncorenlp: filename=vncorenlp-1.0.3-py3-none-any.whl size=2645933 sha256=ff1f5c315efd4ee99c6325c28659278d02d0942c77d0c76b68c6984d3ddceb10
#   Stored in directory: /root/.cache/pip/wheels/6f/19/20/ec7083125fd06db1a19d0d3ca18806ecf4e8ed1464713b4efa
# Successfully built vncorenlp
# Installing collected packages: underthesea_core, python-crfsuite, vncorenlp, underthesea
# Successfully installed python-crfsuite-0.9.11 underthesea-8.3.0 underthesea_core-1.0.5 vncorenlp-1.0.3

# %%
# Import các thư viện cần thiết
import re
import os
import pandas as pd
import numpy as np
from pathlib import Path
import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', 100)

# %%
# Optional
base_zip_folder = '../data/raw_ocr_annual_report.zip'

if not os.path.exists('../data/raw_ocr_annual_report'):
    import zipfile
    with zipfile.ZipFile(base_zip_folder, 'r') as zip_ref:
        zip_ref.extractall('../data/')

# %%
banks = [
    'agribank',
    'bidv',
    'bsc',
    'mbbank',
    'msb',
    'ocb',
    'shb',
    'techcombank',
    'vib',
    'vietabank',
    'vietcombank',
    'viettinbank',
    'vpbank'
]

YEARS = range(2000, 2026)  # 2000 đến 2025
REPORT_TYPES = ['bctn', 'ptbv']
BASE_DIR = '../data/raw_ocr_annual_report'

# %%
from pathlib import Path
from datetime import datetime

def scan_report_files(base_dir, banks, years, report_types):
    """
    Quét tất cả file báo cáo có sẵn

    Cấu trúc thư mục:
    base_dir/
        agribank/
            bctn_2020_raw.txt
            bctn_2021_raw.txt
            ptbv_2021_raw.txt
            ...
        bidv/
            bctn_2020_raw.txt
            ...
    """
    file_list = []


    for bank in banks:
        bank_dir = Path(base_dir) / bank

        if not bank_dir.exists():
            print(f"Folder không tồn tại: {bank}/")
            continue

        bank_files = []

        for year in years:
            for report_type in report_types:
                file_name = f"{report_type}_{year}_raw.txt"
                file_path = bank_dir / file_name

                if file_path.exists():
                    file_size = file_path.stat().st_size / 1024  # KB
                    bank_files.append({
                        'bank': bank,
                        'year': year,
                        'report_type': report_type,
                        'file_path': str(file_path),
                        'file_size_kb': file_size
                    })

        if bank_files:
            file_list.extend(bank_files)
        else:
            print(f"{bank:15s} - Không có file nào")

    print(f"Tổng cộng: {len(file_list)} file")

    return pd.DataFrame(file_list)


df_files = scan_report_files(BASE_DIR, banks, YEARS, REPORT_TYPES)
# Out:
# Tổng cộng: 153 file

# %% [markdown]
# ### Tách câu

# %%
from underthesea import sent_tokenize
from vncorenlp import VnCoreNLP
import time

# %%
def segment_sentences_nlp(text):
    print("phân đoạn câu bằng underthesea...")

    # Loại bỏ khoảng trắng thừa trước khi xử lý
    text = re.sub(r'\s+', ' ', text).strip()

    # Sử dụng underthesea để tách câu
    sentences = sent_tokenize(text)

    # Lọc câu quá ngắn (< 10 ký tự) - có thể là fragment hoặc noise
    filtered_sentences = []
    for sent in sentences:
        sent = sent.strip()
        if len(sent) >= 10:
            filtered_sentences.append(sent)

    print(f"Đã tách thành {len(filtered_sentences):,} câu hợp lệ")
    print(f"Đã lọc bỏ {len(sentences) - len(filtered_sentences):,} câu quá ngắn")

    return filtered_sentences

# %% [markdown]
# ### Tách Từ trong câu

# %%
import os
from vncorenlp import VnCoreNLP

vncorenlp_dir = './VnCoreNLP'
if not os.path.exists(vncorenlp_dir):
    os.makedirs(vncorenlp_dir)
    print(f"Đã tạo thư mục {vncorenlp_dir}")

# Download VnCoreNLP
jar_file = os.path.join(vncorenlp_dir, 'VnCoreNLP-master/VnCoreNLP-1.2.jar')
if not os.path.exists(jar_file):
    print("Đang tải VnCoreNLP...")
    import urllib.request
    import zipfile

    # Download
    url = "https://github.com/vncorenlp/VnCoreNLP/archive/refs/heads/master.zip"
    zip_path = os.path.join(vncorenlp_dir, "VnCoreNLP.zip")
    urllib.request.urlretrieve(url, zip_path)

    # Giải nén
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(vncorenlp_dir)
else:
    print(f"VnCoreNLP đã tồn tại tại {vncorenlp_dir}")
# Out:
# Đã tạo thư mục ./VnCoreNLP
# Đang tải VnCoreNLP...

# %%
def tokenize_sentences_vncorenlp(sentences):
    """
    Tách từ cho danh sách các câu sử dụng VnCoreNLP
    """
    try:
        # annotators="wseg" - chỉ sử dụng word segmentation
        rdrsegmenter = VnCoreNLP("./VnCoreNLP/VnCoreNLP-master/VnCoreNLP-1.2.jar", annotators="wseg", max_heap_size='-Xmx2g')

        tokenized_sentences = []
        total = len(sentences)

        print(f"Đang tách từ cho {total:,} câu...")

        for idx, sent in enumerate(sentences, 1):
            if idx % 100 == 0:
                print(f"  Đã xử lý: {idx}/{total} câu ({idx/total*100:.1f}%)")

            try:
                # Tách từ
                word_segmented = rdrsegmenter.tokenize(sent)

                tokenized_sent = ' '.join([' '.join(x) for x in word_segmented])
                tokenized_sentences.append(tokenized_sent)
            except Exception as e:
                print(f"  Lỗi tại câu {idx}: {str(e)[:50]}")
                tokenized_sentences.append(sent)

        rdrsegmenter.close()

        print(f"Hoàn thành tách từ cho {len(tokenized_sentences):,} câu")
        return tokenized_sentences

    except Exception as e:
        print(f"Lỗi khi khởi tạo VnCoreNLP: {e}")
        return [' '.join(re.findall(r'\w+', sent.lower())) for sent in sentences]

# %% [markdown]
# #### Clean data

# %%
minimal_stopwords = [
    'à', 'ạ', 'ừ', 'ư', 'ơ', 'ô', 'á', 'ấy', 'ầu', 'ào', 'ã', 'ả',
]

# 1. Từ phóng đại/mơ hồ: "rất", "nhiều", "cực kỳ", "đều", "cả"
# 2. Từ phủ định: "không", "chưa", "chẳng"
# 3. Thì động từ: "đã", "sẽ", "đang" (phân biệt cam kết vs thành tựu)
# 4. Mức độ cam kết: "có_thể", "nên", "cần", "phải"
# 5. So sánh: "hơn", "như", "theo", "tương_tự"
# 6. Liên từ quan trọng: "nhưng", "tuy_nhiên", "do_đó"


def clean_and_normalize_text(text, remove_stopwords=False):
    """
    Làm sạch và chuẩn hóa văn bản:

    Chỉ loại bỏ:
    - URL, email
    """
    # Chuyển về chữ thường
    text = text.lower()

    # Loại bỏ URL
    text = re.sub(r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+', '', text)
    text = re.sub(r'www\.(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+', '', text)

    # Loại bỏ email
    text = re.sub(r'\S+@\S+', '', text)

    # Loại bỏ khoảng trắng thừa
    text = re.sub(r'\s+', ' ', text).strip()

    # Tách từ thành list
    words = text.split()

    if remove_stopwords:
        words = [word for word in words if word not in minimal_stopwords]

    # Loại bỏ từ quá ngắn (< 2 ký tự)
    words = [word for word in words if len(word) >= 2]

    return ' '.join(words)

# %% [markdown]
# ### Xử lý file raw

# %%
def process_single_file(file_info, vncorenlp_segmenter):
    """
    Xử lý một file báo cáo:
    1. Đọc file
    2. Tách câu (underthesea)
    3. Tách từ (VnCoreNLP)
    4. Làm sạch
    5. Trả về DataFrame
    """
    try:
        # 1. Đọc file
        with open(file_info['file_path'], 'r', encoding='utf-8') as f:
            raw_text = f.read().strip().replace('##', '').replace('<!-- image -->', '')

            # remove all page number with format \n\n{page_num}\n\n, run loop from 1 to 300, page number like 1 or 01 if contain 1 digits
            for i in range(1, 301):
                raw_text = re.sub(r'\n\n{}\n\n'.format(i), '', raw_text)
                raw_text = re.sub(r'\n\n{}\n\n'.format(str(i).zfill(2)), '', raw_text)

        if len(raw_text) < 100:  # File quá ngắn
            return None, "File quá ngắn"

        # 2. Tách câu
        text = re.sub(r'\s+', ' ', raw_text).strip()
        sentences = segment_sentences_nlp(text)

        if len(sentences) == 0:
            return None, "Không tách được câu"

        # 3. Tách từ
        tokenized_sentences = tokenize_sentences_vncorenlp(sentences)

        # 4. Làm sạch và tạo DataFrame
        data = []
        for idx, (orig_sent, tok_sent) in enumerate(zip(sentences, tokenized_sentences)):
            cleaned = clean_and_normalize_text(tok_sent)

            if len(cleaned.split()) >= 5:
                data.append({
                    'bank': file_info['bank'],
                    'year': file_info['year'],
                    'report_type': file_info['report_type'],
                    'sentence_id': idx,
                    'original_sentence': orig_sent,
                    'tokenized_sentence': tok_sent,
                    'cleaned_sentence': cleaned,
                    'word_count': len(cleaned.split()),
                    'char_count': len(cleaned)
                })

        if len(data) == 0:
            return None, "Không có câu hợp lệ sau làm sạch"

        return pd.DataFrame(data), None

    except Exception as e:
        return None, f"Lỗi: {str(e)[:50]}"


def process_all_files(df_files):
    # Khởi tạo VnCoreNLP
    try:
        rdrsegmenter = VnCoreNLP(
            "./VnCoreNLP/VnCoreNLP-master/VnCoreNLP-1.2.jar",
            annotators="wseg",
            max_heap_size='-Xmx2g'
        )
    except Exception as e:
        print(f"Không thể khởi tạo VnCoreNLP: {e}")
        return None

    all_data = []
    success_count = 0
    fail_count = 0
    total_sentences = 0

    start_time = time.time()

    for idx, file_info in df_files.iterrows():
        progress = (idx + 1) / len(df_files) * 100

        print(f"[{idx+1}/{len(df_files)}] ({progress:.1f}%) Processing: {file_info['bank']}/{file_info['report_type']}_{file_info['year']}_raw.txt")

        df_result, error = process_single_file(file_info, rdrsegmenter)

        if df_result is not None:
            all_data.append(df_result)
            success_count += 1
            total_sentences += len(df_result)
            print(f"{len(df_result):,} câu")
        else:
            fail_count += 1
            print(f"{error}")

    # Đóng VnCoreNLP
    rdrsegmenter.close()

    # Gộp tất cả DataFrame
    if all_data:
        df_final = pd.concat(all_data, ignore_index=True)
    else:
        df_final = pd.DataFrame()

    elapsed_time = time.time() - start_time

    print(f"Thành công:          {success_count}/{len(df_files)} file")
    print(f"Thất bại:            {fail_count}/{len(df_files)} file")
    print("="*70)

    return df_final


# CHẠY XỬ LÝ
if len(df_files) > 0:
    df_all_sentences = process_all_files(df_files)
else:
    print("Không có file để xử lý!")
# Out:
# [1/153] (0.7%) Processing: agribank/bctn_2015_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 331 câu hợp lệ
# Đã lọc bỏ 2 câu quá ngắn
# Đang tách từ cho 331 câu...
#   Đã xử lý: 100/331 câu (30.2%)
#   Đã xử lý: 200/331 câu (60.4%)
#   Đã xử lý: 300/331 câu (90.6%)
# Hoàn thành tách từ cho 331 câu
# 282 câu
# [2/153] (1.3%) Processing: agribank/bctn_2016_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 197 câu hợp lệ
# Đã lọc bỏ 5 câu quá ngắn
# Đang tách từ cho 197 câu...
#   Đã xử lý: 100/197 câu (50.8%)
# Hoàn thành tách từ cho 197 câu
# 197 câu
# [3/153] (2.0%) Processing: agribank/bctn_2017_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 254 câu hợp lệ
# Đã lọc bỏ 0 câu quá ngắn
# Đang tách từ cho 254 câu...
#   Đã xử lý: 100/254 câu (39.4%)
#   Đã xử lý: 200/254 câu (78.7%)
# Hoàn thành tách từ cho 254 câu
# 249 câu
# [4/153] (2.6%) Processing: agribank/bctn_2018_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 303 câu hợp lệ
# Đã lọc bỏ 0 câu quá ngắn
# Đang tách từ cho 303 câu...
#   Đã xử lý: 100/303 câu (33.0%)
#   Đã xử lý: 200/303 câu (66.0%)
#   Đã xử lý: 300/303 câu (99.0%)
# Hoàn thành tách từ cho 303 câu
# 301 câu
# [5/153] (3.3%) Processing: agribank/bctn_2019_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 334 câu hợp lệ
# Đã lọc bỏ 9 câu quá ngắn
# Đang tách từ cho 334 câu...
#   Đã xử lý: 100/334 câu (29.9%)
#   Đã xử lý: 200/334 câu (59.9%)
#   Đã xử lý: 300/334 câu (89.8%)
# Hoàn thành tách từ cho 334 câu
# 333 câu
# [6/153] (3.9%) Processing: agribank/bctn_2020_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 323 câu hợp lệ
# Đã lọc bỏ 20 câu quá ngắn
# Đang tách từ cho 323 câu...
#   Đã xử lý: 100/323 câu (31.0%)
#   Đã xử lý: 200/323 câu (61.9%)
#   Đã xử lý: 300/323 câu (92.9%)
# Hoàn thành tách từ cho 323 câu
# 317 câu
# [7/153] (4.6%) Processing: agribank/bctn_2021_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 238 câu hợp lệ
# Đã lọc bỏ 15 câu quá ngắn
# Đang tách từ cho 238 câu...
#   Đã xử lý: 100/238 câu (42.0%)
#   Đã xử lý: 200/238 câu (84.0%)
# Hoàn thành tách từ cho 238 câu
# 238 câu
# [8/153] (5.2%) Processing: agribank/bctn_2022_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 448 câu hợp lệ
# Đã lọc bỏ 31 câu quá ngắn
# Đang tách từ cho 448 câu...
#   Đã xử lý: 100/448 câu (22.3%)
#   Đã xử lý: 200/448 câu (44.6%)
#   Đã xử lý: 300/448 câu (67.0%)
#   Đã xử lý: 400/448 câu (89.3%)
# Hoàn thành tách từ cho 448 câu
# 446 câu
# [9/153] (5.9%) Processing: agribank/bctn_2023_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 520 câu hợp lệ
# Đã lọc bỏ 51 câu quá ngắn
# Đang tách từ cho 520 câu...
#   Đã xử lý: 100/520 câu (19.2%)
#   Đã xử lý: 200/520 câu (38.5%)
#   Đã xử lý: 300/520 câu (57.7%)
#   Đã xử lý: 400/520 câu (76.9%)
#   Đã xử lý: 500/520 câu (96.2%)
# Hoàn thành tách từ cho 520 câu
# 510 câu
# [10/153] (6.5%) Processing: agribank/bctn_2024_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 681 câu hợp lệ
# Đã lọc bỏ 27 câu quá ngắn
# Đang tách từ cho 681 câu...
#   Đã xử lý: 100/681 câu (14.7%)
#   Đã xử lý: 200/681 câu (29.4%)
#   Đã xử lý: 300/681 câu (44.1%)
#   Đã xử lý: 400/681 câu (58.7%)
#   Đã xử lý: 500/681 câu (73.4%)
#   Đã xử lý: 600/681 câu (88.1%)
# Hoàn thành tách từ cho 681 câu
# 664 câu
# [11/153] (7.2%) Processing: bidv/bctn_2013_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 820 câu hợp lệ
# Đã lọc bỏ 13 câu quá ngắn
# Đang tách từ cho 820 câu...
#   Đã xử lý: 100/820 câu (12.2%)
#   Đã xử lý: 200/820 câu (24.4%)
#   Đã xử lý: 300/820 câu (36.6%)
#   Đã xử lý: 400/820 câu (48.8%)
#   Đã xử lý: 500/820 câu (61.0%)
#   Đã xử lý: 600/820 câu (73.2%)
#   Đã xử lý: 700/820 câu (85.4%)
#   Đã xử lý: 800/820 câu (97.6%)
# Hoàn thành tách từ cho 820 câu
# 777 câu
# [12/153] (7.8%) Processing: bidv/bctn_2014_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 897 câu hợp lệ
# Đã lọc bỏ 39 câu quá ngắn
# Đang tách từ cho 897 câu...
#   Đã xử lý: 100/897 câu (11.1%)
#   Đã xử lý: 200/897 câu (22.3%)
#   Đã xử lý: 300/897 câu (33.4%)
#   Đã xử lý: 400/897 câu (44.6%)
#   Đã xử lý: 500/897 câu (55.7%)
#   Đã xử lý: 600/897 câu (66.9%)
#   Đã xử lý: 700/897 câu (78.0%)
#   Đã xử lý: 800/897 câu (89.2%)
# Hoàn thành tách từ cho 897 câu
# 860 câu
# [13/153] (8.5%) Processing: bidv/bctn_2015_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 1,182 câu hợp lệ
# Đã lọc bỏ 40 câu quá ngắn
# Đang tách từ cho 1,182 câu...
#   Đã xử lý: 100/1182 câu (8.5%)
#   Đã xử lý: 200/1182 câu (16.9%)
#   Đã xử lý: 300/1182 câu (25.4%)
#   Đã xử lý: 400/1182 câu (33.8%)
#   Đã xử lý: 500/1182 câu (42.3%)
#   Đã xử lý: 600/1182 câu (50.8%)
#   Đã xử lý: 700/1182 câu (59.2%)
#   Đã xử lý: 800/1182 câu (67.7%)
#   Đã xử lý: 900/1182 câu (76.1%)
#   Đã xử lý: 1000/1182 câu (84.6%)
#   Đã xử lý: 1100/1182 câu (93.1%)
# Hoàn thành tách từ cho 1,182 câu
# 1,130 câu
# [14/153] (9.2%) Processing: bidv/bctn_2016_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 1,129 câu hợp lệ
# Đã lọc bỏ 33 câu quá ngắn
# Đang tách từ cho 1,129 câu...
#   Đã xử lý: 100/1129 câu (8.9%)
#   Đã xử lý: 200/1129 câu (17.7%)
#   Đã xử lý: 300/1129 câu (26.6%)
#   Đã xử lý: 400/1129 câu (35.4%)
#   Đã xử lý: 500/1129 câu (44.3%)
#   Đã xử lý: 600/1129 câu (53.1%)
#   Đã xử lý: 700/1129 câu (62.0%)
#   Đã xử lý: 800/1129 câu (70.9%)
#   Đã xử lý: 900/1129 câu (79.7%)
#   Đã xử lý: 1000/1129 câu (88.6%)
#   Đã xử lý: 1100/1129 câu (97.4%)
# Hoàn thành tách từ cho 1,129 câu
# 1,047 câu
# [15/153] (9.8%) Processing: bidv/bctn_2017_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 1,152 câu hợp lệ
# Đã lọc bỏ 10 câu quá ngắn
# Đang tách từ cho 1,152 câu...
#   Đã xử lý: 100/1152 câu (8.7%)
#   Đã xử lý: 200/1152 câu (17.4%)
#   Đã xử lý: 300/1152 câu (26.0%)
#   Đã xử lý: 400/1152 câu (34.7%)
#   Đã xử lý: 500/1152 câu (43.4%)
#   Đã xử lý: 600/1152 câu (52.1%)
#   Đã xử lý: 700/1152 câu (60.8%)
#   Đã xử lý: 800/1152 câu (69.4%)
#   Đã xử lý: 900/1152 câu (78.1%)
#   Đã xử lý: 1000/1152 câu (86.8%)
#   Đã xử lý: 1100/1152 câu (95.5%)
# Hoàn thành tách từ cho 1,152 câu
# 1,053 câu
# [16/153] (10.5%) Processing: bidv/bctn_2018_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 995 câu hợp lệ
# Đã lọc bỏ 12 câu quá ngắn
# Đang tách từ cho 995 câu...
#   Đã xử lý: 100/995 câu (10.1%)
#   Đã xử lý: 200/995 câu (20.1%)
#   Đã xử lý: 300/995 câu (30.2%)
#   Đã xử lý: 400/995 câu (40.2%)
#   Đã xử lý: 500/995 câu (50.3%)
#   Đã xử lý: 600/995 câu (60.3%)
#   Đã xử lý: 700/995 câu (70.4%)
#   Đã xử lý: 800/995 câu (80.4%)
#   Đã xử lý: 900/995 câu (90.5%)
# Hoàn thành tách từ cho 995 câu
# 963 câu
# [17/153] (11.1%) Processing: bidv/bctn_2019_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 2,254 câu hợp lệ
# Đã lọc bỏ 3 câu quá ngắn
# Đang tách từ cho 2,254 câu...
#   Đã xử lý: 100/2254 câu (4.4%)
#   Đã xử lý: 200/2254 câu (8.9%)
#   Đã xử lý: 300/2254 câu (13.3%)
#   Đã xử lý: 400/2254 câu (17.7%)
#   Đã xử lý: 500/2254 câu (22.2%)
#   Đã xử lý: 600/2254 câu (26.6%)
#   Đã xử lý: 700/2254 câu (31.1%)
#   Lỗi tại câu 784: HTTPConnectionPool(host='127.0.0.1', port=55325):
#   Lỗi tại câu 798: 400: Unable to parse form content
#   Đã xử lý: 800/2254 câu (35.5%)
#   Đã xử lý: 900/2254 câu (39.9%)
#   Đã xử lý: 1000/2254 câu (44.4%)
#   Đã xử lý: 1100/2254 câu (48.8%)
#   Đã xử lý: 1200/2254 câu (53.2%)
#   Đã xử lý: 1300/2254 câu (57.7%)
#   Đã xử lý: 1400/2254 câu (62.1%)
#   Đã xử lý: 1500/2254 câu (66.5%)
#   Đã xử lý: 1600/2254 câu (71.0%)
#   Đã xử lý: 1700/2254 câu (75.4%)
#   Đã xử lý: 1800/2254 câu (79.9%)
#   Đã xử lý: 1900/2254 câu (84.3%)
#   Đã xử lý: 2000/2254 câu (88.7%)
#   Đã xử lý: 2100/2254 câu (93.2%)
#   Đã xử lý: 2200/2254 câu (97.6%)
# Hoàn thành tách từ cho 2,254 câu
# 2,144 câu
# [18/153] (11.8%) Processing: bidv/bctn_2020_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 1,040 câu hợp lệ
# Đã lọc bỏ 14 câu quá ngắn
# Đang tách từ cho 1,040 câu...
#   Đã xử lý: 100/1040 câu (9.6%)
#   Đã xử lý: 200/1040 câu (19.2%)
#   Đã xử lý: 300/1040 câu (28.8%)
#   Đã xử lý: 400/1040 câu (38.5%)
#   Đã xử lý: 500/1040 câu (48.1%)
#   Đã xử lý: 600/1040 câu (57.7%)
#   Đã xử lý: 700/1040 câu (67.3%)
#   Đã xử lý: 800/1040 câu (76.9%)
#   Đã xử lý: 900/1040 câu (86.5%)
#   Đã xử lý: 1000/1040 câu (96.2%)
# Hoàn thành tách từ cho 1,040 câu
# 1,016 câu
# [19/153] (12.4%) Processing: bidv/bctn_2021_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 1,187 câu hợp lệ
# Đã lọc bỏ 2 câu quá ngắn
# Đang tách từ cho 1,187 câu...
#   Đã xử lý: 100/1187 câu (8.4%)
#   Đã xử lý: 200/1187 câu (16.8%)
#   Đã xử lý: 300/1187 câu (25.3%)
#   Đã xử lý: 400/1187 câu (33.7%)
#   Đã xử lý: 500/1187 câu (42.1%)
#   Đã xử lý: 600/1187 câu (50.5%)
#   Đã xử lý: 700/1187 câu (59.0%)
#   Đã xử lý: 800/1187 câu (67.4%)
#   Đã xử lý: 900/1187 câu (75.8%)
#   Đã xử lý: 1000/1187 câu (84.2%)
#   Đã xử lý: 1100/1187 câu (92.7%)
# Hoàn thành tách từ cho 1,187 câu
# 1,156 câu
# [20/153] (13.1%) Processing: bidv/bctn_2022_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 1,417 câu hợp lệ
# Đã lọc bỏ 1 câu quá ngắn
# Đang tách từ cho 1,417 câu...
#   Đã xử lý: 100/1417 câu (7.1%)
#   Đã xử lý: 200/1417 câu (14.1%)
#   Đã xử lý: 300/1417 câu (21.2%)
#   Đã xử lý: 400/1417 câu (28.2%)
#   Đã xử lý: 500/1417 câu (35.3%)
#   Đã xử lý: 600/1417 câu (42.3%)
#   Đã xử lý: 700/1417 câu (49.4%)
#   Đã xử lý: 800/1417 câu (56.5%)
#   Đã xử lý: 900/1417 câu (63.5%)
#   Đã xử lý: 1000/1417 câu (70.6%)
#   Đã xử lý: 1100/1417 câu (77.6%)
#   Đã xử lý: 1200/1417 câu (84.7%)
#   Đã xử lý: 1300/1417 câu (91.7%)
#   Đã xử lý: 1400/1417 câu (98.8%)
# Hoàn thành tách từ cho 1,417 câu
# 1,383 câu
# [21/153] (13.7%) Processing: bidv/bctn_2023_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 1,200 câu hợp lệ
# Đã lọc bỏ 6 câu quá ngắn
# Đang tách từ cho 1,200 câu...
#   Đã xử lý: 100/1200 câu (8.3%)
#   Đã xử lý: 200/1200 câu (16.7%)
#   Đã xử lý: 300/1200 câu (25.0%)
#   Đã xử lý: 400/1200 câu (33.3%)
#   Đã xử lý: 500/1200 câu (41.7%)
#   Đã xử lý: 600/1200 câu (50.0%)
#   Đã xử lý: 700/1200 câu (58.3%)
#   Đã xử lý: 800/1200 câu (66.7%)
#   Đã xử lý: 900/1200 câu (75.0%)
#   Đã xử lý: 1000/1200 câu (83.3%)
#   Đã xử lý: 1100/1200 câu (91.7%)
#   Đã xử lý: 1200/1200 câu (100.0%)
# Hoàn thành tách từ cho 1,200 câu
# 1,144 câu
# [22/153] (14.4%) Processing: bidv/ptbv_2023_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 518 câu hợp lệ
# Đã lọc bỏ 0 câu quá ngắn
# Đang tách từ cho 518 câu...
#   Đã xử lý: 100/518 câu (19.3%)
#   Đã xử lý: 200/518 câu (38.6%)
#   Đã xử lý: 300/518 câu (57.9%)
#   Đã xử lý: 400/518 câu (77.2%)
#   Đã xử lý: 500/518 câu (96.5%)
# Hoàn thành tách từ cho 518 câu
# 516 câu
# [23/153] (15.0%) Processing: bidv/bctn_2024_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 1,270 câu hợp lệ
# Đã lọc bỏ 9 câu quá ngắn
# Đang tách từ cho 1,270 câu...
#   Đã xử lý: 100/1270 câu (7.9%)
#   Đã xử lý: 200/1270 câu (15.7%)
#   Đã xử lý: 300/1270 câu (23.6%)
#   Đã xử lý: 400/1270 câu (31.5%)
#   Đã xử lý: 500/1270 câu (39.4%)
#   Đã xử lý: 600/1270 câu (47.2%)
#   Đã xử lý: 700/1270 câu (55.1%)
#   Đã xử lý: 800/1270 câu (63.0%)
#   Đã xử lý: 900/1270 câu (70.9%)
#   Đã xử lý: 1000/1270 câu (78.7%)
#   Đã xử lý: 1100/1270 câu (86.6%)
#   Đã xử lý: 1200/1270 câu (94.5%)
# Hoàn thành tách từ cho 1,270 câu
# 1,235 câu
# [24/153] (15.7%) Processing: bidv/ptbv_2024_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 772 câu hợp lệ
# Đã lọc bỏ 0 câu quá ngắn
# Đang tách từ cho 772 câu...
#   Đã xử lý: 100/772 câu (13.0%)
#   Đã xử lý: 200/772 câu (25.9%)
#   Đã xử lý: 300/772 câu (38.9%)
#   Đã xử lý: 400/772 câu (51.8%)
#   Đã xử lý: 500/772 câu (64.8%)
#   Đã xử lý: 600/772 câu (77.7%)
#   Đã xử lý: 700/772 câu (90.7%)
# Hoàn thành tách từ cho 772 câu
# 769 câu
# [25/153] (16.3%) Processing: bsc/bctn_2011_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 489 câu hợp lệ
# Đã lọc bỏ 17 câu quá ngắn
# Đang tách từ cho 489 câu...
#   Đã xử lý: 100/489 câu (20.4%)
#   Đã xử lý: 200/489 câu (40.9%)
#   Đã xử lý: 300/489 câu (61.3%)
#   Đã xử lý: 400/489 câu (81.8%)
# Hoàn thành tách từ cho 489 câu
# 479 câu
# [26/153] (17.0%) Processing: bsc/bctn_2016_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 1,388 câu hợp lệ
# Đã lọc bỏ 57 câu quá ngắn
# Đang tách từ cho 1,388 câu...
#   Đã xử lý: 100/1388 câu (7.2%)
#   Đã xử lý: 200/1388 câu (14.4%)
#   Đã xử lý: 300/1388 câu (21.6%)
#   Đã xử lý: 400/1388 câu (28.8%)
#   Đã xử lý: 500/1388 câu (36.0%)
#   Đã xử lý: 600/1388 câu (43.2%)
#   Đã xử lý: 700/1388 câu (50.4%)
#   Đã xử lý: 800/1388 câu (57.6%)
#   Đã xử lý: 900/1388 câu (64.8%)
#   Đã xử lý: 1000/1388 câu (72.0%)
#   Đã xử lý: 1100/1388 câu (79.3%)
#   Đã xử lý: 1200/1388 câu (86.5%)
#   Đã xử lý: 1300/1388 câu (93.7%)
# Hoàn thành tách từ cho 1,388 câu
# 1,359 câu
# [27/153] (17.6%) Processing: bsc/bctn_2017_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 1,231 câu hợp lệ
# Đã lọc bỏ 21 câu quá ngắn
# Đang tách từ cho 1,231 câu...
#   Đã xử lý: 100/1231 câu (8.1%)
#   Đã xử lý: 200/1231 câu (16.2%)
#   Đã xử lý: 300/1231 câu (24.4%)
#   Đã xử lý: 400/1231 câu (32.5%)
#   Đã xử lý: 500/1231 câu (40.6%)
#   Đã xử lý: 600/1231 câu (48.7%)
#   Đã xử lý: 700/1231 câu (56.9%)
#   Đã xử lý: 800/1231 câu (65.0%)
#   Đã xử lý: 900/1231 câu (73.1%)
#   Đã xử lý: 1000/1231 câu (81.2%)
#   Đã xử lý: 1100/1231 câu (89.4%)
#   Đã xử lý: 1200/1231 câu (97.5%)
# Hoàn thành tách từ cho 1,231 câu
# 1,189 câu
# [28/153] (18.3%) Processing: bsc/bctn_2018_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 1,306 câu hợp lệ
# Đã lọc bỏ 110 câu quá ngắn
# Đang tách từ cho 1,306 câu...
#   Đã xử lý: 100/1306 câu (7.7%)
#   Đã xử lý: 200/1306 câu (15.3%)
#   Đã xử lý: 300/1306 câu (23.0%)
#   Đã xử lý: 400/1306 câu (30.6%)
#   Đã xử lý: 500/1306 câu (38.3%)
#   Đã xử lý: 600/1306 câu (45.9%)
#   Đã xử lý: 700/1306 câu (53.6%)
#   Đã xử lý: 800/1306 câu (61.3%)
#   Đã xử lý: 900/1306 câu (68.9%)
#   Đã xử lý: 1000/1306 câu (76.6%)
#   Đã xử lý: 1100/1306 câu (84.2%)
#   Đã xử lý: 1200/1306 câu (91.9%)
#   Đã xử lý: 1300/1306 câu (99.5%)
# Hoàn thành tách từ cho 1,306 câu
# 1,230 câu
# [29/153] (19.0%) Processing: bsc/bctn_2019_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 1,191 câu hợp lệ
# Đã lọc bỏ 38 câu quá ngắn
# Đang tách từ cho 1,191 câu...
#   Đã xử lý: 100/1191 câu (8.4%)
#   Đã xử lý: 200/1191 câu (16.8%)
#   Đã xử lý: 300/1191 câu (25.2%)
#   Đã xử lý: 400/1191 câu (33.6%)
#   Đã xử lý: 500/1191 câu (42.0%)
#   Đã xử lý: 600/1191 câu (50.4%)
#   Đã xử lý: 700/1191 câu (58.8%)
#   Đã xử lý: 800/1191 câu (67.2%)
#   Đã xử lý: 900/1191 câu (75.6%)
#   Đã xử lý: 1000/1191 câu (84.0%)
#   Đã xử lý: 1100/1191 câu (92.4%)
# Hoàn thành tách từ cho 1,191 câu
# 1,174 câu
# [30/153] (19.6%) Processing: bsc/bctn_2020_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 1 câu hợp lệ
# Đã lọc bỏ 0 câu quá ngắn
# Đang tách từ cho 1 câu...
#   Lỗi tại câu 1: 400: Unable to parse form content
# Hoàn thành tách từ cho 1 câu
# 1 câu
# [31/153] (20.3%) Processing: bsc/bctn_2021_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 1,099 câu hợp lệ
# Đã lọc bỏ 9 câu quá ngắn
# Đang tách từ cho 1,099 câu...
#   Đã xử lý: 100/1099 câu (9.1%)
#   Đã xử lý: 200/1099 câu (18.2%)
#   Đã xử lý: 300/1099 câu (27.3%)
#   Đã xử lý: 400/1099 câu (36.4%)
#   Đã xử lý: 500/1099 câu (45.5%)
#   Đã xử lý: 600/1099 câu (54.6%)
#   Đã xử lý: 700/1099 câu (63.7%)
#   Đã xử lý: 800/1099 câu (72.8%)
#   Đã xử lý: 900/1099 câu (81.9%)
#   Đã xử lý: 1000/1099 câu (91.0%)
# Hoàn thành tách từ cho 1,099 câu
# 1,075 câu
# [32/153] (20.9%) Processing: bsc/bctn_2022_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 1,086 câu hợp lệ
# Đã lọc bỏ 58 câu quá ngắn
# Đang tách từ cho 1,086 câu...
#   Đã xử lý: 100/1086 câu (9.2%)
#   Đã xử lý: 200/1086 câu (18.4%)
#   Đã xử lý: 300/1086 câu (27.6%)
#   Đã xử lý: 400/1086 câu (36.8%)
#   Đã xử lý: 500/1086 câu (46.0%)
#   Đã xử lý: 600/1086 câu (55.2%)
#   Đã xử lý: 700/1086 câu (64.5%)
#   Đã xử lý: 800/1086 câu (73.7%)
#   Đã xử lý: 900/1086 câu (82.9%)
#   Đã xử lý: 1000/1086 câu (92.1%)
# Hoàn thành tách từ cho 1,086 câu
# 1,066 câu
# [33/153] (21.6%) Processing: bsc/bctn_2023_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 1,061 câu hợp lệ
# Đã lọc bỏ 15 câu quá ngắn
# Đang tách từ cho 1,061 câu...
#   Đã xử lý: 100/1061 câu (9.4%)
#   Đã xử lý: 200/1061 câu (18.9%)
#   Đã xử lý: 300/1061 câu (28.3%)
#   Đã xử lý: 400/1061 câu (37.7%)
#   Đã xử lý: 500/1061 câu (47.1%)
#   Đã xử lý: 600/1061 câu (56.6%)
#   Đã xử lý: 700/1061 câu (66.0%)
#   Đã xử lý: 800/1061 câu (75.4%)
#   Đã xử lý: 900/1061 câu (84.8%)
#   Đã xử lý: 1000/1061 câu (94.3%)
# Hoàn thành tách từ cho 1,061 câu
# 1,029 câu
# [34/153] (22.2%) Processing: bsc/bctn_2024_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 1,126 câu hợp lệ
# Đã lọc bỏ 24 câu quá ngắn
# Đang tách từ cho 1,126 câu...
#   Đã xử lý: 100/1126 câu (8.9%)
#   Đã xử lý: 200/1126 câu (17.8%)
#   Đã xử lý: 300/1126 câu (26.6%)
#   Đã xử lý: 400/1126 câu (35.5%)
#   Đã xử lý: 500/1126 câu (44.4%)
#   Đã xử lý: 600/1126 câu (53.3%)
#   Đã xử lý: 700/1126 câu (62.2%)
#   Đã xử lý: 800/1126 câu (71.0%)
#   Đã xử lý: 900/1126 câu (79.9%)
#   Đã xử lý: 1000/1126 câu (88.8%)
#   Đã xử lý: 1100/1126 câu (97.7%)
# Hoàn thành tách từ cho 1,126 câu
# 1,105 câu
# [35/153] (22.9%) Processing: mbbank/bctn_2004_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 557 câu hợp lệ
# Đã lọc bỏ 51 câu quá ngắn
# Đang tách từ cho 557 câu...
#   Đã xử lý: 100/557 câu (18.0%)
#   Đã xử lý: 200/557 câu (35.9%)
#   Đã xử lý: 300/557 câu (53.9%)
#   Đã xử lý: 400/557 câu (71.8%)
#   Đã xử lý: 500/557 câu (89.8%)
# Hoàn thành tách từ cho 557 câu
# 539 câu
# [36/153] (23.5%) Processing: mbbank/bctn_2005_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 217 câu hợp lệ
# Đã lọc bỏ 9 câu quá ngắn
# Đang tách từ cho 217 câu...
#   Đã xử lý: 100/217 câu (46.1%)
#   Đã xử lý: 200/217 câu (92.2%)
# Hoàn thành tách từ cho 217 câu
# 217 câu
# [37/153] (24.2%) Processing: mbbank/bctn_2017_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 958 câu hợp lệ
# Đã lọc bỏ 53 câu quá ngắn
# Đang tách từ cho 958 câu...
#   Đã xử lý: 100/958 câu (10.4%)
#   Đã xử lý: 200/958 câu (20.9%)
#   Đã xử lý: 300/958 câu (31.3%)
#   Đã xử lý: 400/958 câu (41.8%)
#   Đã xử lý: 500/958 câu (52.2%)
#   Đã xử lý: 600/958 câu (62.6%)
#   Đã xử lý: 700/958 câu (73.1%)
#   Đã xử lý: 800/958 câu (83.5%)
#   Đã xử lý: 900/958 câu (93.9%)
# Hoàn thành tách từ cho 958 câu
# 950 câu
# [38/153] (24.8%) Processing: mbbank/bctn_2018_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 855 câu hợp lệ
# Đã lọc bỏ 3 câu quá ngắn
# Đang tách từ cho 855 câu...
#   Đã xử lý: 100/855 câu (11.7%)
#   Đã xử lý: 200/855 câu (23.4%)
#   Đã xử lý: 300/855 câu (35.1%)
#   Đã xử lý: 400/855 câu (46.8%)
#   Đã xử lý: 500/855 câu (58.5%)
#   Đã xử lý: 600/855 câu (70.2%)
#   Đã xử lý: 700/855 câu (81.9%)
#   Đã xử lý: 800/855 câu (93.6%)
# Hoàn thành tách từ cho 855 câu
# 843 câu
# [39/153] (25.5%) Processing: mbbank/bctn_2019_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 1,040 câu hợp lệ
# Đã lọc bỏ 55 câu quá ngắn
# Đang tách từ cho 1,040 câu...
#   Đã xử lý: 100/1040 câu (9.6%)
#   Đã xử lý: 200/1040 câu (19.2%)
#   Đã xử lý: 300/1040 câu (28.8%)
#   Đã xử lý: 400/1040 câu (38.5%)
#   Đã xử lý: 500/1040 câu (48.1%)
#   Đã xử lý: 600/1040 câu (57.7%)
#   Đã xử lý: 700/1040 câu (67.3%)
#   Đã xử lý: 800/1040 câu (76.9%)
#   Đã xử lý: 900/1040 câu (86.5%)
#   Đã xử lý: 1000/1040 câu (96.2%)
# Hoàn thành tách từ cho 1,040 câu
# 1,016 câu
# [40/153] (26.1%) Processing: mbbank/bctn_2020_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 1,079 câu hợp lệ
# Đã lọc bỏ 16 câu quá ngắn
# Đang tách từ cho 1,079 câu...
#   Đã xử lý: 100/1079 câu (9.3%)
#   Đã xử lý: 200/1079 câu (18.5%)
#   Đã xử lý: 300/1079 câu (27.8%)
#   Đã xử lý: 400/1079 câu (37.1%)
#   Đã xử lý: 500/1079 câu (46.3%)
#   Đã xử lý: 600/1079 câu (55.6%)
#   Đã xử lý: 700/1079 câu (64.9%)
#   Đã xử lý: 800/1079 câu (74.1%)
#   Đã xử lý: 900/1079 câu (83.4%)
#   Đã xử lý: 1000/1079 câu (92.7%)
# Hoàn thành tách từ cho 1,079 câu
# 915 câu
# [41/153] (26.8%) Processing: mbbank/bctn_2021_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 1,157 câu hợp lệ
# Đã lọc bỏ 44 câu quá ngắn
# Đang tách từ cho 1,157 câu...
#   Đã xử lý: 100/1157 câu (8.6%)
#   Đã xử lý: 200/1157 câu (17.3%)
#   Đã xử lý: 300/1157 câu (25.9%)
#   Đã xử lý: 400/1157 câu (34.6%)
#   Đã xử lý: 500/1157 câu (43.2%)
#   Đã xử lý: 600/1157 câu (51.9%)
#   Đã xử lý: 700/1157 câu (60.5%)
#   Đã xử lý: 800/1157 câu (69.1%)
#   Đã xử lý: 900/1157 câu (77.8%)
#   Đã xử lý: 1000/1157 câu (86.4%)
#   Đã xử lý: 1100/1157 câu (95.1%)
# Hoàn thành tách từ cho 1,157 câu
# 1,148 câu
# [42/153] (27.5%) Processing: mbbank/bctn_2022_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 1,206 câu hợp lệ
# Đã lọc bỏ 2 câu quá ngắn
# Đang tách từ cho 1,206 câu...
#   Đã xử lý: 100/1206 câu (8.3%)
#   Đã xử lý: 200/1206 câu (16.6%)
#   Đã xử lý: 300/1206 câu (24.9%)
#   Đã xử lý: 400/1206 câu (33.2%)
#   Đã xử lý: 500/1206 câu (41.5%)
#   Đã xử lý: 600/1206 câu (49.8%)
#   Đã xử lý: 700/1206 câu (58.0%)
#   Đã xử lý: 800/1206 câu (66.3%)
#   Đã xử lý: 900/1206 câu (74.6%)
#   Đã xử lý: 1000/1206 câu (82.9%)
#   Đã xử lý: 1100/1206 câu (91.2%)
#   Đã xử lý: 1200/1206 câu (99.5%)
# Hoàn thành tách từ cho 1,206 câu
# 1,201 câu
# [43/153] (28.1%) Processing: mbbank/bctn_2023_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 1,053 câu hợp lệ
# Đã lọc bỏ 6 câu quá ngắn
# Đang tách từ cho 1,053 câu...
#   Đã xử lý: 100/1053 câu (9.5%)
#   Đã xử lý: 200/1053 câu (19.0%)
#   Đã xử lý: 300/1053 câu (28.5%)
#   Đã xử lý: 400/1053 câu (38.0%)
#   Đã xử lý: 500/1053 câu (47.5%)
#   Đã xử lý: 600/1053 câu (57.0%)
#   Đã xử lý: 700/1053 câu (66.5%)
#   Đã xử lý: 800/1053 câu (76.0%)
#   Đã xử lý: 900/1053 câu (85.5%)
#   Đã xử lý: 1000/1053 câu (95.0%)
# Hoàn thành tách từ cho 1,053 câu
# 1,045 câu
# [44/153] (28.8%) Processing: mbbank/bctn_2024_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 2,077 câu hợp lệ
# Đã lọc bỏ 13 câu quá ngắn
# Đang tách từ cho 2,077 câu...
#   Đã xử lý: 100/2077 câu (4.8%)
#   Đã xử lý: 200/2077 câu (9.6%)
#   Đã xử lý: 300/2077 câu (14.4%)
#   Đã xử lý: 400/2077 câu (19.3%)
#   Đã xử lý: 500/2077 câu (24.1%)
#   Đã xử lý: 600/2077 câu (28.9%)
#   Đã xử lý: 700/2077 câu (33.7%)
#   Đã xử lý: 800/2077 câu (38.5%)
#   Đã xử lý: 900/2077 câu (43.3%)
#   Đã xử lý: 1000/2077 câu (48.1%)
#   Đã xử lý: 1100/2077 câu (53.0%)
#   Đã xử lý: 1200/2077 câu (57.8%)
#   Đã xử lý: 1300/2077 câu (62.6%)
#   Đã xử lý: 1400/2077 câu (67.4%)
#   Đã xử lý: 1500/2077 câu (72.2%)
#   Đã xử lý: 1600/2077 câu (77.0%)
#   Đã xử lý: 1700/2077 câu (81.8%)
#   Đã xử lý: 1800/2077 câu (86.7%)
#   Đã xử lý: 1900/2077 câu (91.5%)
#   Đã xử lý: 2000/2077 câu (96.3%)
# Hoàn thành tách từ cho 2,077 câu
# 2,069 câu
# [45/153] (29.4%) Processing: msb/bctn_2011_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 732 câu hợp lệ
# Đã lọc bỏ 51 câu quá ngắn
# Đang tách từ cho 732 câu...
#   Đã xử lý: 100/732 câu (13.7%)
#   Đã xử lý: 200/732 câu (27.3%)
#   Đã xử lý: 300/732 câu (41.0%)
#   Đã xử lý: 400/732 câu (54.6%)
#   Đã xử lý: 500/732 câu (68.3%)
#   Đã xử lý: 600/732 câu (82.0%)
#   Đã xử lý: 700/732 câu (95.6%)
# Hoàn thành tách từ cho 732 câu
# 725 câu
# [46/153] (30.1%) Processing: msb/bctn_2012_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 938 câu hợp lệ
# Đã lọc bỏ 23 câu quá ngắn
# Đang tách từ cho 938 câu...
#   Đã xử lý: 100/938 câu (10.7%)
#   Đã xử lý: 200/938 câu (21.3%)
#   Đã xử lý: 300/938 câu (32.0%)
#   Đã xử lý: 400/938 câu (42.6%)
#   Đã xử lý: 500/938 câu (53.3%)
#   Đã xử lý: 600/938 câu (64.0%)
#   Đã xử lý: 700/938 câu (74.6%)
#   Đã xử lý: 800/938 câu (85.3%)
#   Đã xử lý: 900/938 câu (95.9%)
# Hoàn thành tách từ cho 938 câu
# 827 câu
# [47/153] (30.7%) Processing: msb/bctn_2013_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 729 câu hợp lệ
# Đã lọc bỏ 8 câu quá ngắn
# Đang tách từ cho 729 câu...
#   Đã xử lý: 100/729 câu (13.7%)
#   Đã xử lý: 200/729 câu (27.4%)
#   Đã xử lý: 300/729 câu (41.2%)
#   Đã xử lý: 400/729 câu (54.9%)
#   Đã xử lý: 500/729 câu (68.6%)
#   Đã xử lý: 600/729 câu (82.3%)
#   Đã xử lý: 700/729 câu (96.0%)
# Hoàn thành tách từ cho 729 câu
# 713 câu
# [48/153] (31.4%) Processing: msb/bctn_2014_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 674 câu hợp lệ
# Đã lọc bỏ 31 câu quá ngắn
# Đang tách từ cho 674 câu...
#   Đã xử lý: 100/674 câu (14.8%)
#   Đã xử lý: 200/674 câu (29.7%)
#   Đã xử lý: 300/674 câu (44.5%)
#   Đã xử lý: 400/674 câu (59.3%)
#   Đã xử lý: 500/674 câu (74.2%)
#   Đã xử lý: 600/674 câu (89.0%)
# Hoàn thành tách từ cho 674 câu
# 655 câu
# [49/153] (32.0%) Processing: msb/bctn_2015_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 699 câu hợp lệ
# Đã lọc bỏ 18 câu quá ngắn
# Đang tách từ cho 699 câu...
#   Đã xử lý: 100/699 câu (14.3%)
#   Đã xử lý: 200/699 câu (28.6%)
#   Đã xử lý: 300/699 câu (42.9%)
#   Đã xử lý: 400/699 câu (57.2%)
#   Đã xử lý: 500/699 câu (71.5%)
#   Đã xử lý: 600/699 câu (85.8%)
# Hoàn thành tách từ cho 699 câu
# 661 câu
# [50/153] (32.7%) Processing: msb/bctn_2016_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 786 câu hợp lệ
# Đã lọc bỏ 10 câu quá ngắn
# Đang tách từ cho 786 câu...
#   Đã xử lý: 100/786 câu (12.7%)
#   Đã xử lý: 200/786 câu (25.4%)
#   Đã xử lý: 300/786 câu (38.2%)
#   Đã xử lý: 400/786 câu (50.9%)
#   Đã xử lý: 500/786 câu (63.6%)
#   Đã xử lý: 600/786 câu (76.3%)
#   Đã xử lý: 700/786 câu (89.1%)
# Hoàn thành tách từ cho 786 câu
# 779 câu
# [51/153] (33.3%) Processing: msb/bctn_2017_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 762 câu hợp lệ
# Đã lọc bỏ 7 câu quá ngắn
# Đang tách từ cho 762 câu...
#   Đã xử lý: 100/762 câu (13.1%)
#   Đã xử lý: 200/762 câu (26.2%)
#   Đã xử lý: 300/762 câu (39.4%)
#   Đã xử lý: 400/762 câu (52.5%)
#   Đã xử lý: 500/762 câu (65.6%)
#   Đã xử lý: 600/762 câu (78.7%)
#   Đã xử lý: 700/762 câu (91.9%)
# Hoàn thành tách từ cho 762 câu
# 753 câu
# [52/153] (34.0%) Processing: msb/bctn_2018_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 856 câu hợp lệ
# Đã lọc bỏ 11 câu quá ngắn
# Đang tách từ cho 856 câu...
#   Đã xử lý: 100/856 câu (11.7%)
#   Đã xử lý: 200/856 câu (23.4%)
#   Đã xử lý: 300/856 câu (35.0%)
#   Đã xử lý: 400/856 câu (46.7%)
#   Đã xử lý: 500/856 câu (58.4%)
#   Đã xử lý: 600/856 câu (70.1%)
#   Đã xử lý: 700/856 câu (81.8%)
#   Đã xử lý: 800/856 câu (93.5%)
# Hoàn thành tách từ cho 856 câu
# 840 câu
# [53/153] (34.6%) Processing: msb/bctn_2019_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 858 câu hợp lệ
# Đã lọc bỏ 8 câu quá ngắn
# Đang tách từ cho 858 câu...
#   Đã xử lý: 100/858 câu (11.7%)
#   Đã xử lý: 200/858 câu (23.3%)
#   Đã xử lý: 300/858 câu (35.0%)
#   Đã xử lý: 400/858 câu (46.6%)
#   Đã xử lý: 500/858 câu (58.3%)
#   Đã xử lý: 600/858 câu (69.9%)
#   Đã xử lý: 700/858 câu (81.6%)
#   Đã xử lý: 800/858 câu (93.2%)
# Hoàn thành tách từ cho 858 câu
# 849 câu
# [54/153] (35.3%) Processing: msb/bctn_2020_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 1,096 câu hợp lệ
# Đã lọc bỏ 11 câu quá ngắn
# Đang tách từ cho 1,096 câu...
#   Đã xử lý: 100/1096 câu (9.1%)
#   Đã xử lý: 200/1096 câu (18.2%)
#   Đã xử lý: 300/1096 câu (27.4%)
#   Đã xử lý: 400/1096 câu (36.5%)
#   Đã xử lý: 500/1096 câu (45.6%)
#   Đã xử lý: 600/1096 câu (54.7%)
#   Đã xử lý: 700/1096 câu (63.9%)
#   Đã xử lý: 800/1096 câu (73.0%)
#   Đã xử lý: 900/1096 câu (82.1%)
#   Đã xử lý: 1000/1096 câu (91.2%)
# Hoàn thành tách từ cho 1,096 câu
# 1,086 câu
# [55/153] (35.9%) Processing: msb/bctn_2021_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 1,447 câu hợp lệ
# Đã lọc bỏ 78 câu quá ngắn
# Đang tách từ cho 1,447 câu...
#   Đã xử lý: 100/1447 câu (6.9%)
#   Đã xử lý: 200/1447 câu (13.8%)
#   Đã xử lý: 300/1447 câu (20.7%)
#   Đã xử lý: 400/1447 câu (27.6%)
#   Đã xử lý: 500/1447 câu (34.6%)
#   Đã xử lý: 600/1447 câu (41.5%)
#   Đã xử lý: 700/1447 câu (48.4%)
#   Đã xử lý: 800/1447 câu (55.3%)
#   Đã xử lý: 900/1447 câu (62.2%)
#   Đã xử lý: 1000/1447 câu (69.1%)
#   Đã xử lý: 1100/1447 câu (76.0%)
#   Đã xử lý: 1200/1447 câu (82.9%)
#   Đã xử lý: 1300/1447 câu (89.8%)
#   Đã xử lý: 1400/1447 câu (96.8%)
# Hoàn thành tách từ cho 1,447 câu
# 1,424 câu
# [56/153] (36.6%) Processing: msb/bctn_2023_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 449 câu hợp lệ
# Đã lọc bỏ 9 câu quá ngắn
# Đang tách từ cho 449 câu...
#   Đã xử lý: 100/449 câu (22.3%)
#   Đã xử lý: 200/449 câu (44.5%)
#   Đã xử lý: 300/449 câu (66.8%)
#   Đã xử lý: 400/449 câu (89.1%)
# Hoàn thành tách từ cho 449 câu
# 447 câu
# [57/153] (37.3%) Processing: msb/bctn_2024_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 1,547 câu hợp lệ
# Đã lọc bỏ 30 câu quá ngắn
# Đang tách từ cho 1,547 câu...
#   Đã xử lý: 100/1547 câu (6.5%)
#   Đã xử lý: 200/1547 câu (12.9%)
#   Đã xử lý: 300/1547 câu (19.4%)
#   Đã xử lý: 400/1547 câu (25.9%)
#   Đã xử lý: 500/1547 câu (32.3%)
#   Đã xử lý: 600/1547 câu (38.8%)
#   Đã xử lý: 700/1547 câu (45.2%)
#   Đã xử lý: 800/1547 câu (51.7%)
#   Đã xử lý: 900/1547 câu (58.2%)
#   Đã xử lý: 1000/1547 câu (64.6%)
#   Đã xử lý: 1100/1547 câu (71.1%)
#   Đã xử lý: 1200/1547 câu (77.6%)
#   Đã xử lý: 1300/1547 câu (84.0%)
#   Đã xử lý: 1400/1547 câu (90.5%)
#   Đã xử lý: 1500/1547 câu (97.0%)
# Hoàn thành tách từ cho 1,547 câu
# 1,532 câu
# [58/153] (37.9%) Processing: ocb/bctn_2011_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 229 câu hợp lệ
# Đã lọc bỏ 4 câu quá ngắn
# Đang tách từ cho 229 câu...
#   Đã xử lý: 100/229 câu (43.7%)
#   Đã xử lý: 200/229 câu (87.3%)
# Hoàn thành tách từ cho 229 câu
# 226 câu
# [59/153] (38.6%) Processing: ocb/bctn_2012_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 282 câu hợp lệ
# Đã lọc bỏ 19 câu quá ngắn
# Đang tách từ cho 282 câu...
#   Đã xử lý: 100/282 câu (35.5%)
#   Đã xử lý: 200/282 câu (70.9%)
# Hoàn thành tách từ cho 282 câu
# 273 câu
# [60/153] (39.2%) Processing: ocb/bctn_2013_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 295 câu hợp lệ
# Đã lọc bỏ 12 câu quá ngắn
# Đang tách từ cho 295 câu...
#   Đã xử lý: 100/295 câu (33.9%)
#   Đã xử lý: 200/295 câu (67.8%)
# Hoàn thành tách từ cho 295 câu
# 289 câu
# [61/153] (39.9%) Processing: ocb/bctn_2014_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 233 câu hợp lệ
# Đã lọc bỏ 40 câu quá ngắn
# Đang tách từ cho 233 câu...
#   Đã xử lý: 100/233 câu (42.9%)
#   Đã xử lý: 200/233 câu (85.8%)
# Hoàn thành tách từ cho 233 câu
# 220 câu
# [62/153] (40.5%) Processing: ocb/bctn_2015_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 407 câu hợp lệ
# Đã lọc bỏ 24 câu quá ngắn
# Đang tách từ cho 407 câu...
#   Đã xử lý: 100/407 câu (24.6%)
#   Đã xử lý: 200/407 câu (49.1%)
#   Đã xử lý: 300/407 câu (73.7%)
#   Đã xử lý: 400/407 câu (98.3%)
# Hoàn thành tách từ cho 407 câu
# 389 câu
# [63/153] (41.2%) Processing: ocb/bctn_2016_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 379 câu hợp lệ
# Đã lọc bỏ 20 câu quá ngắn
# Đang tách từ cho 379 câu...
#   Đã xử lý: 100/379 câu (26.4%)
#   Đã xử lý: 200/379 câu (52.8%)
#   Đã xử lý: 300/379 câu (79.2%)
# Hoàn thành tách từ cho 379 câu
# 361 câu
# [64/153] (41.8%) Processing: ocb/bctn_2017_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 456 câu hợp lệ
# Đã lọc bỏ 39 câu quá ngắn
# Đang tách từ cho 456 câu...
#   Đã xử lý: 100/456 câu (21.9%)
#   Đã xử lý: 200/456 câu (43.9%)
#   Đã xử lý: 300/456 câu (65.8%)
#   Đã xử lý: 400/456 câu (87.7%)
# Hoàn thành tách từ cho 456 câu
# 444 câu
# [65/153] (42.5%) Processing: ocb/bctn_2018_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 426 câu hợp lệ
# Đã lọc bỏ 34 câu quá ngắn
# Đang tách từ cho 426 câu...
#   Đã xử lý: 100/426 câu (23.5%)
#   Đã xử lý: 200/426 câu (46.9%)
#   Đã xử lý: 300/426 câu (70.4%)
#   Đã xử lý: 400/426 câu (93.9%)
# Hoàn thành tách từ cho 426 câu
# 411 câu
# [66/153] (43.1%) Processing: ocb/bctn_2019_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 404 câu hợp lệ
# Đã lọc bỏ 33 câu quá ngắn
# Đang tách từ cho 404 câu...
#   Đã xử lý: 100/404 câu (24.8%)
#   Đã xử lý: 200/404 câu (49.5%)
#   Đã xử lý: 300/404 câu (74.3%)
#   Đã xử lý: 400/404 câu (99.0%)
# Hoàn thành tách từ cho 404 câu
# 381 câu
# [67/153] (43.8%) Processing: ocb/bctn_2020_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 327 câu hợp lệ
# Đã lọc bỏ 0 câu quá ngắn
# Đang tách từ cho 327 câu...
#   Đã xử lý: 100/327 câu (30.6%)
#   Đã xử lý: 200/327 câu (61.2%)
#   Đã xử lý: 300/327 câu (91.7%)
# Hoàn thành tách từ cho 327 câu
# 324 câu
# [68/153] (44.4%) Processing: ocb/bctn_2021_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 1 câu hợp lệ
# Đã lọc bỏ 0 câu quá ngắn
# Đang tách từ cho 1 câu...
# Hoàn thành tách từ cho 1 câu
# Không có câu hợp lệ sau làm sạch
# [69/153] (45.1%) Processing: ocb/bctn_2022_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 1 câu hợp lệ
# Đã lọc bỏ 0 câu quá ngắn
# Đang tách từ cho 1 câu...
# Hoàn thành tách từ cho 1 câu
# Không có câu hợp lệ sau làm sạch
# [70/153] (45.8%) Processing: ocb/bctn_2023_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 563 câu hợp lệ
# Đã lọc bỏ 20 câu quá ngắn
# Đang tách từ cho 563 câu...
#   Đã xử lý: 100/563 câu (17.8%)
#   Đã xử lý: 200/563 câu (35.5%)
#   Đã xử lý: 300/563 câu (53.3%)
#   Đã xử lý: 400/563 câu (71.0%)
#   Đã xử lý: 500/563 câu (88.8%)
# Hoàn thành tách từ cho 563 câu
# 555 câu
# [71/153] (46.4%) Processing: ocb/ptbv_2023_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 1,186 câu hợp lệ
# Đã lọc bỏ 3 câu quá ngắn
# Đang tách từ cho 1,186 câu...
#   Đã xử lý: 100/1186 câu (8.4%)
#   Đã xử lý: 200/1186 câu (16.9%)
#   Đã xử lý: 300/1186 câu (25.3%)
#   Đã xử lý: 400/1186 câu (33.7%)
#   Đã xử lý: 500/1186 câu (42.2%)
#   Đã xử lý: 600/1186 câu (50.6%)
#   Đã xử lý: 700/1186 câu (59.0%)
#   Đã xử lý: 800/1186 câu (67.5%)
#   Đã xử lý: 900/1186 câu (75.9%)
#   Đã xử lý: 1000/1186 câu (84.3%)
#   Đã xử lý: 1100/1186 câu (92.7%)
# Hoàn thành tách từ cho 1,186 câu
# 1,174 câu
# [72/153] (47.1%) Processing: shb/bctn_2010_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 1,201 câu hợp lệ
# Đã lọc bỏ 116 câu quá ngắn
# Đang tách từ cho 1,201 câu...
#   Đã xử lý: 100/1201 câu (8.3%)
#   Đã xử lý: 200/1201 câu (16.7%)
#   Đã xử lý: 300/1201 câu (25.0%)
#   Đã xử lý: 400/1201 câu (33.3%)
#   Đã xử lý: 500/1201 câu (41.6%)
#   Đã xử lý: 600/1201 câu (50.0%)
#   Đã xử lý: 700/1201 câu (58.3%)
#   Đã xử lý: 800/1201 câu (66.6%)
#   Đã xử lý: 900/1201 câu (74.9%)
#   Đã xử lý: 1000/1201 câu (83.3%)
#   Đã xử lý: 1100/1201 câu (91.6%)
#   Đã xử lý: 1200/1201 câu (99.9%)
# Hoàn thành tách từ cho 1,201 câu
# 1,146 câu
# [73/153] (47.7%) Processing: shb/bctn_2011_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 1,068 câu hợp lệ
# Đã lọc bỏ 30 câu quá ngắn
# Đang tách từ cho 1,068 câu...
#   Đã xử lý: 100/1068 câu (9.4%)
#   Đã xử lý: 200/1068 câu (18.7%)
#   Đã xử lý: 300/1068 câu (28.1%)
#   Đã xử lý: 400/1068 câu (37.5%)
#   Đã xử lý: 500/1068 câu (46.8%)
#   Đã xử lý: 600/1068 câu (56.2%)
#   Đã xử lý: 700/1068 câu (65.5%)
#   Đã xử lý: 800/1068 câu (74.9%)
#   Đã xử lý: 900/1068 câu (84.3%)
#   Đã xử lý: 1000/1068 câu (93.6%)
# Hoàn thành tách từ cho 1,068 câu
# 1,058 câu
# [74/153] (48.4%) Processing: shb/bctn_2012_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 976 câu hợp lệ
# Đã lọc bỏ 30 câu quá ngắn
# Đang tách từ cho 976 câu...
#   Đã xử lý: 100/976 câu (10.2%)
#   Đã xử lý: 200/976 câu (20.5%)
#   Đã xử lý: 300/976 câu (30.7%)
#   Đã xử lý: 400/976 câu (41.0%)
#   Đã xử lý: 500/976 câu (51.2%)
#   Đã xử lý: 600/976 câu (61.5%)
#   Đã xử lý: 700/976 câu (71.7%)
#   Đã xử lý: 800/976 câu (82.0%)
#   Đã xử lý: 900/976 câu (92.2%)
# Hoàn thành tách từ cho 976 câu
# 960 câu
# [75/153] (49.0%) Processing: shb/bctn_2013_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 882 câu hợp lệ
# Đã lọc bỏ 38 câu quá ngắn
# Đang tách từ cho 882 câu...
#   Đã xử lý: 100/882 câu (11.3%)
#   Đã xử lý: 200/882 câu (22.7%)
#   Đã xử lý: 300/882 câu (34.0%)
#   Đã xử lý: 400/882 câu (45.4%)
#   Đã xử lý: 500/882 câu (56.7%)
#   Đã xử lý: 600/882 câu (68.0%)
#   Đã xử lý: 700/882 câu (79.4%)
#   Đã xử lý: 800/882 câu (90.7%)
# Hoàn thành tách từ cho 882 câu
# 870 câu
# [76/153] (49.7%) Processing: shb/bctn_2014_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 898 câu hợp lệ
# Đã lọc bỏ 57 câu quá ngắn
# Đang tách từ cho 898 câu...
#   Đã xử lý: 100/898 câu (11.1%)
#   Đã xử lý: 200/898 câu (22.3%)
#   Đã xử lý: 300/898 câu (33.4%)
#   Đã xử lý: 400/898 câu (44.5%)
#   Đã xử lý: 500/898 câu (55.7%)
#   Đã xử lý: 600/898 câu (66.8%)
#   Đã xử lý: 700/898 câu (78.0%)
#   Đã xử lý: 800/898 câu (89.1%)
# Hoàn thành tách từ cho 898 câu
# 891 câu
# [77/153] (50.3%) Processing: shb/bctn_2016_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 833 câu hợp lệ
# Đã lọc bỏ 13 câu quá ngắn
# Đang tách từ cho 833 câu...
#   Đã xử lý: 100/833 câu (12.0%)
#   Đã xử lý: 200/833 câu (24.0%)
#   Đã xử lý: 300/833 câu (36.0%)
#   Đã xử lý: 400/833 câu (48.0%)
#   Đã xử lý: 500/833 câu (60.0%)
#   Đã xử lý: 600/833 câu (72.0%)
#   Đã xử lý: 700/833 câu (84.0%)
#   Đã xử lý: 800/833 câu (96.0%)
# Hoàn thành tách từ cho 833 câu
# 824 câu
# [78/153] (51.0%) Processing: shb/bctn_2018_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 955 câu hợp lệ
# Đã lọc bỏ 29 câu quá ngắn
# Đang tách từ cho 955 câu...
#   Đã xử lý: 100/955 câu (10.5%)
#   Đã xử lý: 200/955 câu (20.9%)
#   Đã xử lý: 300/955 câu (31.4%)
#   Đã xử lý: 400/955 câu (41.9%)
#   Đã xử lý: 500/955 câu (52.4%)
#   Đã xử lý: 600/955 câu (62.8%)
#   Đã xử lý: 700/955 câu (73.3%)
#   Đã xử lý: 800/955 câu (83.8%)
#   Đã xử lý: 900/955 câu (94.2%)
# Hoàn thành tách từ cho 955 câu
# 945 câu
# [79/153] (51.6%) Processing: shb/bctn_2019_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 1,140 câu hợp lệ
# Đã lọc bỏ 52 câu quá ngắn
# Đang tách từ cho 1,140 câu...
#   Đã xử lý: 100/1140 câu (8.8%)
#   Đã xử lý: 200/1140 câu (17.5%)
#   Đã xử lý: 300/1140 câu (26.3%)
#   Đã xử lý: 400/1140 câu (35.1%)
#   Đã xử lý: 500/1140 câu (43.9%)
#   Đã xử lý: 600/1140 câu (52.6%)
#   Đã xử lý: 700/1140 câu (61.4%)
#   Đã xử lý: 800/1140 câu (70.2%)
#   Đã xử lý: 900/1140 câu (78.9%)
#   Đã xử lý: 1000/1140 câu (87.7%)
#   Đã xử lý: 1100/1140 câu (96.5%)
# Hoàn thành tách từ cho 1,140 câu
# 1,130 câu
# [80/153] (52.3%) Processing: shb/bctn_2020_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 1,227 câu hợp lệ
# Đã lọc bỏ 74 câu quá ngắn
# Đang tách từ cho 1,227 câu...
#   Đã xử lý: 100/1227 câu (8.1%)
#   Đã xử lý: 200/1227 câu (16.3%)
#   Đã xử lý: 300/1227 câu (24.4%)
#   Đã xử lý: 400/1227 câu (32.6%)
#   Đã xử lý: 500/1227 câu (40.7%)
#   Đã xử lý: 600/1227 câu (48.9%)
#   Đã xử lý: 700/1227 câu (57.0%)
#   Đã xử lý: 800/1227 câu (65.2%)
#   Đã xử lý: 900/1227 câu (73.3%)
#   Đã xử lý: 1000/1227 câu (81.5%)
#   Đã xử lý: 1100/1227 câu (89.6%)
#   Đã xử lý: 1200/1227 câu (97.8%)
# Hoàn thành tách từ cho 1,227 câu
# 1,209 câu
# [81/153] (52.9%) Processing: shb/bctn_2021_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 1,269 câu hợp lệ
# Đã lọc bỏ 63 câu quá ngắn
# Đang tách từ cho 1,269 câu...
#   Đã xử lý: 100/1269 câu (7.9%)
#   Đã xử lý: 200/1269 câu (15.8%)
#   Đã xử lý: 300/1269 câu (23.6%)
#   Đã xử lý: 400/1269 câu (31.5%)
#   Đã xử lý: 500/1269 câu (39.4%)
#   Đã xử lý: 600/1269 câu (47.3%)
#   Đã xử lý: 700/1269 câu (55.2%)
#   Đã xử lý: 800/1269 câu (63.0%)
#   Đã xử lý: 900/1269 câu (70.9%)
#   Đã xử lý: 1000/1269 câu (78.8%)
#   Đã xử lý: 1100/1269 câu (86.7%)
#   Đã xử lý: 1200/1269 câu (94.6%)
# Hoàn thành tách từ cho 1,269 câu
# 1,250 câu
# [82/153] (53.6%) Processing: shb/bctn_2022_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 1,519 câu hợp lệ
# Đã lọc bỏ 64 câu quá ngắn
# Đang tách từ cho 1,519 câu...
#   Đã xử lý: 100/1519 câu (6.6%)
#   Đã xử lý: 200/1519 câu (13.2%)
#   Đã xử lý: 300/1519 câu (19.7%)
#   Đã xử lý: 400/1519 câu (26.3%)
#   Đã xử lý: 500/1519 câu (32.9%)
#   Đã xử lý: 600/1519 câu (39.5%)
#   Đã xử lý: 700/1519 câu (46.1%)
#   Đã xử lý: 800/1519 câu (52.7%)
#   Đã xử lý: 900/1519 câu (59.2%)
#   Đã xử lý: 1000/1519 câu (65.8%)
#   Đã xử lý: 1100/1519 câu (72.4%)
#   Đã xử lý: 1200/1519 câu (79.0%)
#   Đã xử lý: 1300/1519 câu (85.6%)
#   Đã xử lý: 1400/1519 câu (92.2%)
#   Đã xử lý: 1500/1519 câu (98.7%)
# Hoàn thành tách từ cho 1,519 câu
# 1,490 câu
# [83/153] (54.2%) Processing: shb/bctn_2023_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 1,659 câu hợp lệ
# Đã lọc bỏ 78 câu quá ngắn
# Đang tách từ cho 1,659 câu...
#   Đã xử lý: 100/1659 câu (6.0%)
#   Đã xử lý: 200/1659 câu (12.1%)
#   Đã xử lý: 300/1659 câu (18.1%)
#   Đã xử lý: 400/1659 câu (24.1%)
#   Đã xử lý: 500/1659 câu (30.1%)
#   Đã xử lý: 600/1659 câu (36.2%)
#   Đã xử lý: 700/1659 câu (42.2%)
#   Đã xử lý: 800/1659 câu (48.2%)
#   Đã xử lý: 900/1659 câu (54.2%)
#   Đã xử lý: 1000/1659 câu (60.3%)
#   Đã xử lý: 1100/1659 câu (66.3%)
#   Đã xử lý: 1200/1659 câu (72.3%)
#   Đã xử lý: 1300/1659 câu (78.4%)
#   Đã xử lý: 1400/1659 câu (84.4%)
#   Đã xử lý: 1500/1659 câu (90.4%)
#   Đã xử lý: 1600/1659 câu (96.4%)
# Hoàn thành tách từ cho 1,659 câu
# 1,615 câu
# [84/153] (54.9%) Processing: shb/bctn_2024_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 1,798 câu hợp lệ
# Đã lọc bỏ 84 câu quá ngắn
# Đang tách từ cho 1,798 câu...
#   Đã xử lý: 100/1798 câu (5.6%)
#   Đã xử lý: 200/1798 câu (11.1%)
#   Đã xử lý: 300/1798 câu (16.7%)
#   Đã xử lý: 400/1798 câu (22.2%)
#   Đã xử lý: 500/1798 câu (27.8%)
#   Đã xử lý: 600/1798 câu (33.4%)
#   Đã xử lý: 700/1798 câu (38.9%)
#   Đã xử lý: 800/1798 câu (44.5%)
#   Đã xử lý: 900/1798 câu (50.1%)
#   Đã xử lý: 1000/1798 câu (55.6%)
#   Đã xử lý: 1100/1798 câu (61.2%)
#   Đã xử lý: 1200/1798 câu (66.7%)
#   Đã xử lý: 1300/1798 câu (72.3%)
#   Đã xử lý: 1400/1798 câu (77.9%)
#   Đã xử lý: 1500/1798 câu (83.4%)
#   Đã xử lý: 1600/1798 câu (89.0%)
#   Đã xử lý: 1700/1798 câu (94.5%)
# Hoàn thành tách từ cho 1,798 câu
# 1,785 câu
# [85/153] (55.6%) Processing: techcombank/bctn_2018_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 1,280 câu hợp lệ
# Đã lọc bỏ 38 câu quá ngắn
# Đang tách từ cho 1,280 câu...
#   Đã xử lý: 100/1280 câu (7.8%)
#   Đã xử lý: 200/1280 câu (15.6%)
#   Đã xử lý: 300/1280 câu (23.4%)
#   Đã xử lý: 400/1280 câu (31.2%)
#   Đã xử lý: 500/1280 câu (39.1%)
#   Đã xử lý: 600/1280 câu (46.9%)
#   Đã xử lý: 700/1280 câu (54.7%)
#   Đã xử lý: 800/1280 câu (62.5%)
#   Đã xử lý: 900/1280 câu (70.3%)
#   Đã xử lý: 1000/1280 câu (78.1%)
#   Đã xử lý: 1100/1280 câu (85.9%)
#   Đã xử lý: 1200/1280 câu (93.8%)
# Hoàn thành tách từ cho 1,280 câu
# 1,269 câu
# [86/153] (56.2%) Processing: techcombank/bctn_2019_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 1,311 câu hợp lệ
# Đã lọc bỏ 8 câu quá ngắn
# Đang tách từ cho 1,311 câu...
#   Đã xử lý: 100/1311 câu (7.6%)
#   Đã xử lý: 200/1311 câu (15.3%)
#   Đã xử lý: 300/1311 câu (22.9%)
#   Đã xử lý: 400/1311 câu (30.5%)
#   Đã xử lý: 500/1311 câu (38.1%)
#   Đã xử lý: 600/1311 câu (45.8%)
#   Đã xử lý: 700/1311 câu (53.4%)
#   Đã xử lý: 800/1311 câu (61.0%)
#   Đã xử lý: 900/1311 câu (68.6%)
#   Đã xử lý: 1000/1311 câu (76.3%)
#   Đã xử lý: 1100/1311 câu (83.9%)
#   Đã xử lý: 1200/1311 câu (91.5%)
#   Đã xử lý: 1300/1311 câu (99.2%)
# Hoàn thành tách từ cho 1,311 câu
# 1,306 câu
# [87/153] (56.9%) Processing: techcombank/bctn_2020_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 1,287 câu hợp lệ
# Đã lọc bỏ 9 câu quá ngắn
# Đang tách từ cho 1,287 câu...
#   Đã xử lý: 100/1287 câu (7.8%)
#   Đã xử lý: 200/1287 câu (15.5%)
#   Đã xử lý: 300/1287 câu (23.3%)
#   Đã xử lý: 400/1287 câu (31.1%)
#   Đã xử lý: 500/1287 câu (38.9%)
#   Đã xử lý: 600/1287 câu (46.6%)
#   Đã xử lý: 700/1287 câu (54.4%)
#   Đã xử lý: 800/1287 câu (62.2%)
#   Đã xử lý: 900/1287 câu (69.9%)
#   Đã xử lý: 1000/1287 câu (77.7%)
#   Đã xử lý: 1100/1287 câu (85.5%)
#   Đã xử lý: 1200/1287 câu (93.2%)
# Hoàn thành tách từ cho 1,287 câu
# 1,280 câu
# [88/153] (57.5%) Processing: techcombank/bctn_2021_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 1,326 câu hợp lệ
# Đã lọc bỏ 27 câu quá ngắn
# Đang tách từ cho 1,326 câu...
#   Đã xử lý: 100/1326 câu (7.5%)
#   Đã xử lý: 200/1326 câu (15.1%)
#   Đã xử lý: 300/1326 câu (22.6%)
#   Đã xử lý: 400/1326 câu (30.2%)
#   Đã xử lý: 500/1326 câu (37.7%)
#   Đã xử lý: 600/1326 câu (45.2%)
#   Đã xử lý: 700/1326 câu (52.8%)
#   Đã xử lý: 800/1326 câu (60.3%)
#   Đã xử lý: 900/1326 câu (67.9%)
#   Đã xử lý: 1000/1326 câu (75.4%)
#   Đã xử lý: 1100/1326 câu (83.0%)
#   Đã xử lý: 1200/1326 câu (90.5%)
#   Đã xử lý: 1300/1326 câu (98.0%)
# Hoàn thành tách từ cho 1,326 câu
# 1,312 câu
# [89/153] (58.2%) Processing: techcombank/bctn_2022_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 1,673 câu hợp lệ
# Đã lọc bỏ 83 câu quá ngắn
# Đang tách từ cho 1,673 câu...
#   Đã xử lý: 100/1673 câu (6.0%)
#   Đã xử lý: 200/1673 câu (12.0%)
#   Đã xử lý: 300/1673 câu (17.9%)
#   Đã xử lý: 400/1673 câu (23.9%)
#   Đã xử lý: 500/1673 câu (29.9%)
#   Đã xử lý: 600/1673 câu (35.9%)
#   Đã xử lý: 700/1673 câu (41.8%)
#   Đã xử lý: 800/1673 câu (47.8%)
#   Đã xử lý: 900/1673 câu (53.8%)
#   Đã xử lý: 1000/1673 câu (59.8%)
#   Đã xử lý: 1100/1673 câu (65.8%)
#   Đã xử lý: 1200/1673 câu (71.7%)
#   Đã xử lý: 1300/1673 câu (77.7%)
#   Đã xử lý: 1400/1673 câu (83.7%)
#   Đã xử lý: 1500/1673 câu (89.7%)
#   Đã xử lý: 1600/1673 câu (95.6%)
# Hoàn thành tách từ cho 1,673 câu
# 1,648 câu
# [90/153] (58.8%) Processing: techcombank/bctn_2023_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 1,913 câu hợp lệ
# Đã lọc bỏ 102 câu quá ngắn
# Đang tách từ cho 1,913 câu...
#   Đã xử lý: 100/1913 câu (5.2%)
#   Đã xử lý: 200/1913 câu (10.5%)
#   Đã xử lý: 300/1913 câu (15.7%)
#   Đã xử lý: 400/1913 câu (20.9%)
#   Đã xử lý: 500/1913 câu (26.1%)
#   Đã xử lý: 600/1913 câu (31.4%)
#   Đã xử lý: 700/1913 câu (36.6%)
#   Đã xử lý: 800/1913 câu (41.8%)
#   Đã xử lý: 900/1913 câu (47.0%)
#   Đã xử lý: 1000/1913 câu (52.3%)
#   Lỗi tại câu 1021: 400: Unable to parse form content
#   Đã xử lý: 1100/1913 câu (57.5%)
#   Đã xử lý: 1200/1913 câu (62.7%)
#   Đã xử lý: 1300/1913 câu (68.0%)
#   Đã xử lý: 1400/1913 câu (73.2%)
#   Đã xử lý: 1500/1913 câu (78.4%)
#   Đã xử lý: 1600/1913 câu (83.6%)
#   Đã xử lý: 1700/1913 câu (88.9%)
#   Đã xử lý: 1800/1913 câu (94.1%)
#   Đã xử lý: 1900/1913 câu (99.3%)
# Hoàn thành tách từ cho 1,913 câu
# 1,888 câu
# [91/153] (59.5%) Processing: techcombank/bctn_2024_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 2,820 câu hợp lệ
# Đã lọc bỏ 72 câu quá ngắn
# Đang tách từ cho 2,820 câu...
#   Đã xử lý: 100/2820 câu (3.5%)
#   Đã xử lý: 200/2820 câu (7.1%)
#   Đã xử lý: 300/2820 câu (10.6%)
#   Đã xử lý: 400/2820 câu (14.2%)
#   Đã xử lý: 500/2820 câu (17.7%)
#   Đã xử lý: 600/2820 câu (21.3%)
#   Đã xử lý: 700/2820 câu (24.8%)
#   Đã xử lý: 800/2820 câu (28.4%)
#   Đã xử lý: 900/2820 câu (31.9%)
#   Đã xử lý: 1000/2820 câu (35.5%)
#   Đã xử lý: 1100/2820 câu (39.0%)
#   Đã xử lý: 1200/2820 câu (42.6%)
#   Đã xử lý: 1300/2820 câu (46.1%)
#   Đã xử lý: 1400/2820 câu (49.6%)
#   Đã xử lý: 1500/2820 câu (53.2%)
#   Đã xử lý: 1600/2820 câu (56.7%)
#   Đã xử lý: 1700/2820 câu (60.3%)
#   Đã xử lý: 1800/2820 câu (63.8%)
#   Đã xử lý: 1900/2820 câu (67.4%)
#   Đã xử lý: 2000/2820 câu (70.9%)
#   Đã xử lý: 2100/2820 câu (74.5%)
#   Đã xử lý: 2200/2820 câu (78.0%)
#   Đã xử lý: 2300/2820 câu (81.6%)
#   Lỗi tại câu 2392: 400: Unable to parse form content
#   Đã xử lý: 2400/2820 câu (85.1%)
#   Đã xử lý: 2500/2820 câu (88.7%)
#   Đã xử lý: 2600/2820 câu (92.2%)
#   Đã xử lý: 2700/2820 câu (95.7%)
#   Đã xử lý: 2800/2820 câu (99.3%)
# Hoàn thành tách từ cho 2,820 câu
# 2,797 câu
# [92/153] (60.1%) Processing: techcombank/ptbv_2024_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 403 câu hợp lệ
# Đã lọc bỏ 0 câu quá ngắn
# Đang tách từ cho 403 câu...
#   Đã xử lý: 100/403 câu (24.8%)
#   Đã xử lý: 200/403 câu (49.6%)
#   Đã xử lý: 300/403 câu (74.4%)
#   Đã xử lý: 400/403 câu (99.3%)
# Hoàn thành tách từ cho 403 câu
# 400 câu
# [93/153] (60.8%) Processing: vib/bctn_2015_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 1,504 câu hợp lệ
# Đã lọc bỏ 35 câu quá ngắn
# Đang tách từ cho 1,504 câu...
#   Đã xử lý: 100/1504 câu (6.6%)
#   Đã xử lý: 200/1504 câu (13.3%)
#   Đã xử lý: 300/1504 câu (19.9%)
#   Đã xử lý: 400/1504 câu (26.6%)
#   Đã xử lý: 500/1504 câu (33.2%)
#   Đã xử lý: 600/1504 câu (39.9%)
#   Đã xử lý: 700/1504 câu (46.5%)
#   Đã xử lý: 800/1504 câu (53.2%)
#   Đã xử lý: 900/1504 câu (59.8%)
#   Đã xử lý: 1000/1504 câu (66.5%)
#   Đã xử lý: 1100/1504 câu (73.1%)
#   Đã xử lý: 1200/1504 câu (79.8%)
#   Đã xử lý: 1300/1504 câu (86.4%)
#   Đã xử lý: 1400/1504 câu (93.1%)
#   Đã xử lý: 1500/1504 câu (99.7%)
# Hoàn thành tách từ cho 1,504 câu
# 1,488 câu
# [94/153] (61.4%) Processing: vib/bctn_2016_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 1 câu hợp lệ
# Đã lọc bỏ 0 câu quá ngắn
# Đang tách từ cho 1 câu...
# Hoàn thành tách từ cho 1 câu
# Không có câu hợp lệ sau làm sạch
# [95/153] (62.1%) Processing: vib/bctn_2017_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 481 câu hợp lệ
# Đã lọc bỏ 0 câu quá ngắn
# Đang tách từ cho 481 câu...
#   Đã xử lý: 100/481 câu (20.8%)
#   Đã xử lý: 200/481 câu (41.6%)
#   Đã xử lý: 300/481 câu (62.4%)
#   Đã xử lý: 400/481 câu (83.2%)
# Hoàn thành tách từ cho 481 câu
# 478 câu
# [96/153] (62.7%) Processing: vib/bctn_2018_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 1,176 câu hợp lệ
# Đã lọc bỏ 95 câu quá ngắn
# Đang tách từ cho 1,176 câu...
#   Đã xử lý: 100/1176 câu (8.5%)
#   Đã xử lý: 200/1176 câu (17.0%)
#   Đã xử lý: 300/1176 câu (25.5%)
#   Đã xử lý: 400/1176 câu (34.0%)
#   Đã xử lý: 500/1176 câu (42.5%)
#   Đã xử lý: 600/1176 câu (51.0%)
#   Đã xử lý: 700/1176 câu (59.5%)
#   Đã xử lý: 800/1176 câu (68.0%)
#   Đã xử lý: 900/1176 câu (76.5%)
#   Đã xử lý: 1000/1176 câu (85.0%)
#   Đã xử lý: 1100/1176 câu (93.5%)
# Hoàn thành tách từ cho 1,176 câu
# 1,166 câu
# [97/153] (63.4%) Processing: vib/bctn_2019_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 1 câu hợp lệ
# Đã lọc bỏ 0 câu quá ngắn
# Đang tách từ cho 1 câu...
# Hoàn thành tách từ cho 1 câu
# Không có câu hợp lệ sau làm sạch
# [98/153] (64.1%) Processing: vib/bctn_2020_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 1 câu hợp lệ
# ...
# 1,147 câu
# [129/153] (84.3%) Processing: viettinbank/bctn_2017_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 1,105 câu hợp lệ
# Đã lọc bỏ 69 câu quá ngắn
# Đang tách từ cho 1,105 câu...
#   Đã xử lý: 100/1105 câu (9.0%)
#   Đã xử lý: 200/1105 câu (18.1%)
#   Đã xử lý: 300/1105 câu (27.1%)
#   Đã xử lý: 400/1105 câu (36.2%)
#   Đã xử lý: 500/1105 câu (45.2%)
#   Đã xử lý: 600/1105 câu (54.3%)
#   Đã xử lý: 700/1105 câu (63.3%)
#   Đã xử lý: 800/1105 câu (72.4%)
#   Đã xử lý: 900/1105 câu (81.4%)
#   Đã xử lý: 1000/1105 câu (90.5%)
#   Đã xử lý: 1100/1105 câu (99.5%)
# Hoàn thành tách từ cho 1,105 câu
# 1,091 câu
# [130/153] (85.0%) Processing: viettinbank/bctn_2018_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 1,212 câu hợp lệ
# Đã lọc bỏ 72 câu quá ngắn
# Đang tách từ cho 1,212 câu...
#   Đã xử lý: 100/1212 câu (8.3%)
#   Đã xử lý: 200/1212 câu (16.5%)
#   Đã xử lý: 300/1212 câu (24.8%)
#   Đã xử lý: 400/1212 câu (33.0%)
#   Đã xử lý: 500/1212 câu (41.3%)
#   Đã xử lý: 600/1212 câu (49.5%)
#   Đã xử lý: 700/1212 câu (57.8%)
#   Đã xử lý: 800/1212 câu (66.0%)
#   Đã xử lý: 900/1212 câu (74.3%)
#   Đã xử lý: 1000/1212 câu (82.5%)
#   Đã xử lý: 1100/1212 câu (90.8%)
#   Đã xử lý: 1200/1212 câu (99.0%)
# Hoàn thành tách từ cho 1,212 câu
# 1,182 câu
# [131/153] (85.6%) Processing: viettinbank/bctn_2019_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 1,351 câu hợp lệ
# Đã lọc bỏ 73 câu quá ngắn
# Đang tách từ cho 1,351 câu...
#   Đã xử lý: 100/1351 câu (7.4%)
#   Đã xử lý: 200/1351 câu (14.8%)
#   Đã xử lý: 300/1351 câu (22.2%)
#   Đã xử lý: 400/1351 câu (29.6%)
#   Đã xử lý: 500/1351 câu (37.0%)
#   Đã xử lý: 600/1351 câu (44.4%)
#   Đã xử lý: 700/1351 câu (51.8%)
#   Đã xử lý: 800/1351 câu (59.2%)
#   Đã xử lý: 900/1351 câu (66.6%)
#   Đã xử lý: 1000/1351 câu (74.0%)
#   Đã xử lý: 1100/1351 câu (81.4%)
#   Đã xử lý: 1200/1351 câu (88.8%)
#   Đã xử lý: 1300/1351 câu (96.2%)
# Hoàn thành tách từ cho 1,351 câu
# 1,302 câu
# [132/153] (86.3%) Processing: viettinbank/bctn_2020_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 1,357 câu hợp lệ
# Đã lọc bỏ 68 câu quá ngắn
# Đang tách từ cho 1,357 câu...
#   Đã xử lý: 100/1357 câu (7.4%)
#   Đã xử lý: 200/1357 câu (14.7%)
#   Đã xử lý: 300/1357 câu (22.1%)
#   Đã xử lý: 400/1357 câu (29.5%)
#   Đã xử lý: 500/1357 câu (36.8%)
#   Đã xử lý: 600/1357 câu (44.2%)
#   Đã xử lý: 700/1357 câu (51.6%)
#   Đã xử lý: 800/1357 câu (59.0%)
#   Đã xử lý: 900/1357 câu (66.3%)
#   Đã xử lý: 1000/1357 câu (73.7%)
#   Đã xử lý: 1100/1357 câu (81.1%)
#   Đã xử lý: 1200/1357 câu (88.4%)
#   Đã xử lý: 1300/1357 câu (95.8%)
# Hoàn thành tách từ cho 1,357 câu
# 1,328 câu
# [133/153] (86.9%) Processing: viettinbank/bctn_2021_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 1,348 câu hợp lệ
# Đã lọc bỏ 27 câu quá ngắn
# Đang tách từ cho 1,348 câu...
#   Đã xử lý: 100/1348 câu (7.4%)
#   Đã xử lý: 200/1348 câu (14.8%)
#   Đã xử lý: 300/1348 câu (22.3%)
#   Đã xử lý: 400/1348 câu (29.7%)
#   Đã xử lý: 500/1348 câu (37.1%)
#   Đã xử lý: 600/1348 câu (44.5%)
#   Đã xử lý: 700/1348 câu (51.9%)
#   Đã xử lý: 800/1348 câu (59.3%)
#   Đã xử lý: 900/1348 câu (66.8%)
#   Đã xử lý: 1000/1348 câu (74.2%)
#   Đã xử lý: 1100/1348 câu (81.6%)
#   Đã xử lý: 1200/1348 câu (89.0%)
#   Đã xử lý: 1300/1348 câu (96.4%)
# Hoàn thành tách từ cho 1,348 câu
# 1,316 câu
# [134/153] (87.6%) Processing: viettinbank/bctn_2022_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 1,325 câu hợp lệ
# Đã lọc bỏ 13 câu quá ngắn
# Đang tách từ cho 1,325 câu...
#   Đã xử lý: 100/1325 câu (7.5%)
#   Đã xử lý: 200/1325 câu (15.1%)
#   Đã xử lý: 300/1325 câu (22.6%)
#   Đã xử lý: 400/1325 câu (30.2%)
#   Đã xử lý: 500/1325 câu (37.7%)
#   Đã xử lý: 600/1325 câu (45.3%)
#   Đã xử lý: 700/1325 câu (52.8%)
#   Đã xử lý: 800/1325 câu (60.4%)
#   Đã xử lý: 900/1325 câu (67.9%)
#   Đã xử lý: 1000/1325 câu (75.5%)
#   Đã xử lý: 1100/1325 câu (83.0%)
#   Đã xử lý: 1200/1325 câu (90.6%)
#   Đã xử lý: 1300/1325 câu (98.1%)
# Hoàn thành tách từ cho 1,325 câu
# 1,290 câu
# [135/153] (88.2%) Processing: viettinbank/bctn_2023_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 2,734 câu hợp lệ
# Đã lọc bỏ 48 câu quá ngắn
# Đang tách từ cho 2,734 câu...
#   Đã xử lý: 100/2734 câu (3.7%)
#   Đã xử lý: 200/2734 câu (7.3%)
#   Đã xử lý: 300/2734 câu (11.0%)
#   Đã xử lý: 400/2734 câu (14.6%)
#   Đã xử lý: 500/2734 câu (18.3%)
#   Đã xử lý: 600/2734 câu (21.9%)
#   Đã xử lý: 700/2734 câu (25.6%)
#   Đã xử lý: 800/2734 câu (29.3%)
#   Đã xử lý: 900/2734 câu (32.9%)
#   Đã xử lý: 1000/2734 câu (36.6%)
#   Đã xử lý: 1100/2734 câu (40.2%)
#   Đã xử lý: 1200/2734 câu (43.9%)
#   Đã xử lý: 1300/2734 câu (47.5%)
#   Đã xử lý: 1400/2734 câu (51.2%)
#   Đã xử lý: 1500/2734 câu (54.9%)
#   Đã xử lý: 1600/2734 câu (58.5%)
#   Đã xử lý: 1700/2734 câu (62.2%)
#   Đã xử lý: 1800/2734 câu (65.8%)
#   Đã xử lý: 1900/2734 câu (69.5%)
#   Đã xử lý: 2000/2734 câu (73.2%)
#   Đã xử lý: 2100/2734 câu (76.8%)
#   Đã xử lý: 2200/2734 câu (80.5%)
#   Đã xử lý: 2300/2734 câu (84.1%)
#   Đã xử lý: 2400/2734 câu (87.8%)
#   Đã xử lý: 2500/2734 câu (91.4%)
#   Đã xử lý: 2600/2734 câu (95.1%)
#   Đã xử lý: 2700/2734 câu (98.8%)
# Hoàn thành tách từ cho 2,734 câu
# 2,639 câu
# [136/153] (88.9%) Processing: viettinbank/bctn_2024_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 2,925 câu hợp lệ
# Đã lọc bỏ 62 câu quá ngắn
# Đang tách từ cho 2,925 câu...
#   Đã xử lý: 100/2925 câu (3.4%)
#   Đã xử lý: 200/2925 câu (6.8%)
#   Đã xử lý: 300/2925 câu (10.3%)
#   Đã xử lý: 400/2925 câu (13.7%)
#   Đã xử lý: 500/2925 câu (17.1%)
#   Đã xử lý: 600/2925 câu (20.5%)
#   Đã xử lý: 700/2925 câu (23.9%)
#   Đã xử lý: 800/2925 câu (27.4%)
#   Đã xử lý: 900/2925 câu (30.8%)
#   Đã xử lý: 1000/2925 câu (34.2%)
#   Đã xử lý: 1100/2925 câu (37.6%)
#   Đã xử lý: 1200/2925 câu (41.0%)
#   Đã xử lý: 1300/2925 câu (44.4%)
#   Đã xử lý: 1400/2925 câu (47.9%)
#   Đã xử lý: 1500/2925 câu (51.3%)
#   Đã xử lý: 1600/2925 câu (54.7%)
#   Đã xử lý: 1700/2925 câu (58.1%)
#   Đã xử lý: 1800/2925 câu (61.5%)
#   Đã xử lý: 1900/2925 câu (65.0%)
#   Đã xử lý: 2000/2925 câu (68.4%)
#   Đã xử lý: 2100/2925 câu (71.8%)
#   Đã xử lý: 2200/2925 câu (75.2%)
#   Đã xử lý: 2300/2925 câu (78.6%)
#   Đã xử lý: 2400/2925 câu (82.1%)
#   Đã xử lý: 2500/2925 câu (85.5%)
#   Đã xử lý: 2600/2925 câu (88.9%)
#   Đã xử lý: 2700/2925 câu (92.3%)
#   Đã xử lý: 2800/2925 câu (95.7%)
#   Đã xử lý: 2900/2925 câu (99.1%)
# Hoàn thành tách từ cho 2,925 câu
# 2,819 câu
# [137/153] (89.5%) Processing: vpbank/bctn_2009_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 423 câu hợp lệ
# Đã lọc bỏ 1 câu quá ngắn
# Đang tách từ cho 423 câu...
#   Đã xử lý: 100/423 câu (23.6%)
#   Đã xử lý: 200/423 câu (47.3%)
#   Đã xử lý: 300/423 câu (70.9%)
#   Đã xử lý: 400/423 câu (94.6%)
# Hoàn thành tách từ cho 423 câu
# 418 câu
# [138/153] (90.2%) Processing: vpbank/bctn_2010_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 286 câu hợp lệ
# Đã lọc bỏ 0 câu quá ngắn
# Đang tách từ cho 286 câu...
#   Đã xử lý: 100/286 câu (35.0%)
#   Đã xử lý: 200/286 câu (69.9%)
# Hoàn thành tách từ cho 286 câu
# 281 câu
# [139/153] (90.8%) Processing: vpbank/bctn_2011_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 419 câu hợp lệ
# Đã lọc bỏ 5 câu quá ngắn
# Đang tách từ cho 419 câu...
#   Đã xử lý: 100/419 câu (23.9%)
#   Đã xử lý: 200/419 câu (47.7%)
#   Đã xử lý: 300/419 câu (71.6%)
#   Đã xử lý: 400/419 câu (95.5%)
# Hoàn thành tách từ cho 419 câu
# 412 câu
# [140/153] (91.5%) Processing: vpbank/bctn_2012_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 1,156 câu hợp lệ
# Đã lọc bỏ 61 câu quá ngắn
# Đang tách từ cho 1,156 câu...
#   Đã xử lý: 100/1156 câu (8.7%)
#   Đã xử lý: 200/1156 câu (17.3%)
#   Đã xử lý: 300/1156 câu (26.0%)
#   Đã xử lý: 400/1156 câu (34.6%)
#   Đã xử lý: 500/1156 câu (43.3%)
#   Đã xử lý: 600/1156 câu (51.9%)
#   Đã xử lý: 700/1156 câu (60.6%)
#   Đã xử lý: 800/1156 câu (69.2%)
#   Đã xử lý: 900/1156 câu (77.9%)
#   Đã xử lý: 1000/1156 câu (86.5%)
#   Đã xử lý: 1100/1156 câu (95.2%)
# Hoàn thành tách từ cho 1,156 câu
# 1,134 câu
# [141/153] (92.2%) Processing: vpbank/bctn_2013_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 993 câu hợp lệ
# Đã lọc bỏ 64 câu quá ngắn
# Đang tách từ cho 993 câu...
#   Đã xử lý: 100/993 câu (10.1%)
#   Đã xử lý: 200/993 câu (20.1%)
#   Đã xử lý: 300/993 câu (30.2%)
#   Đã xử lý: 400/993 câu (40.3%)
#   Đã xử lý: 500/993 câu (50.4%)
#   Đã xử lý: 600/993 câu (60.4%)
#   Đã xử lý: 700/993 câu (70.5%)
#   Đã xử lý: 800/993 câu (80.6%)
#   Đã xử lý: 900/993 câu (90.6%)
# Hoàn thành tách từ cho 993 câu
# 986 câu
# [142/153] (92.8%) Processing: vpbank/bctn_2014_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 1,140 câu hợp lệ
# Đã lọc bỏ 59 câu quá ngắn
# Đang tách từ cho 1,140 câu...
#   Đã xử lý: 100/1140 câu (8.8%)
#   Đã xử lý: 200/1140 câu (17.5%)
#   Đã xử lý: 300/1140 câu (26.3%)
#   Đã xử lý: 400/1140 câu (35.1%)
#   Đã xử lý: 500/1140 câu (43.9%)
#   Đã xử lý: 600/1140 câu (52.6%)
#   Đã xử lý: 700/1140 câu (61.4%)
#   Đã xử lý: 800/1140 câu (70.2%)
#   Đã xử lý: 900/1140 câu (78.9%)
#   Đã xử lý: 1000/1140 câu (87.7%)
#   Đã xử lý: 1100/1140 câu (96.5%)
# Hoàn thành tách từ cho 1,140 câu
# 1,130 câu
# [143/153] (93.5%) Processing: vpbank/bctn_2015_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 1,100 câu hợp lệ
# Đã lọc bỏ 83 câu quá ngắn
# Đang tách từ cho 1,100 câu...
#   Đã xử lý: 100/1100 câu (9.1%)
#   Đã xử lý: 200/1100 câu (18.2%)
#   Đã xử lý: 300/1100 câu (27.3%)
#   Đã xử lý: 400/1100 câu (36.4%)
#   Đã xử lý: 500/1100 câu (45.5%)
#   Đã xử lý: 600/1100 câu (54.5%)
#   Đã xử lý: 700/1100 câu (63.6%)
#   Đã xử lý: 800/1100 câu (72.7%)
#   Đã xử lý: 900/1100 câu (81.8%)
#   Đã xử lý: 1000/1100 câu (90.9%)
#   Đã xử lý: 1100/1100 câu (100.0%)
# Hoàn thành tách từ cho 1,100 câu
# 1,087 câu
# [144/153] (94.1%) Processing: vpbank/bctn_2016_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 1,099 câu hợp lệ
# Đã lọc bỏ 41 câu quá ngắn
# Đang tách từ cho 1,099 câu...
#   Đã xử lý: 100/1099 câu (9.1%)
#   Đã xử lý: 200/1099 câu (18.2%)
#   Đã xử lý: 300/1099 câu (27.3%)
#   Đã xử lý: 400/1099 câu (36.4%)
#   Đã xử lý: 500/1099 câu (45.5%)
#   Đã xử lý: 600/1099 câu (54.6%)
#   Đã xử lý: 700/1099 câu (63.7%)
#   Đã xử lý: 800/1099 câu (72.8%)
#   Đã xử lý: 900/1099 câu (81.9%)
#   Đã xử lý: 1000/1099 câu (91.0%)
# Hoàn thành tách từ cho 1,099 câu
# 1,084 câu
# [145/153] (94.8%) Processing: vpbank/bctn_2017_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 1,376 câu hợp lệ
# Đã lọc bỏ 57 câu quá ngắn
# Đang tách từ cho 1,376 câu...
#   Đã xử lý: 100/1376 câu (7.3%)
#   Đã xử lý: 200/1376 câu (14.5%)
#   Đã xử lý: 300/1376 câu (21.8%)
#   Đã xử lý: 400/1376 câu (29.1%)
#   Đã xử lý: 500/1376 câu (36.3%)
#   Đã xử lý: 600/1376 câu (43.6%)
#   Đã xử lý: 700/1376 câu (50.9%)
#   Đã xử lý: 800/1376 câu (58.1%)
#   Đã xử lý: 900/1376 câu (65.4%)
#   Đã xử lý: 1000/1376 câu (72.7%)
#   Đã xử lý: 1100/1376 câu (79.9%)
#   Đã xử lý: 1200/1376 câu (87.2%)
#   Đã xử lý: 1300/1376 câu (94.5%)
# Hoàn thành tách từ cho 1,376 câu
# 1,339 câu
# [146/153] (95.4%) Processing: vpbank/bctn_2018_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 990 câu hợp lệ
# Đã lọc bỏ 19 câu quá ngắn
# Đang tách từ cho 990 câu...
#   Đã xử lý: 100/990 câu (10.1%)
#   Đã xử lý: 200/990 câu (20.2%)
#   Đã xử lý: 300/990 câu (30.3%)
#   Đã xử lý: 400/990 câu (40.4%)
#   Đã xử lý: 500/990 câu (50.5%)
#   Đã xử lý: 600/990 câu (60.6%)
#   Đã xử lý: 700/990 câu (70.7%)
#   Đã xử lý: 800/990 câu (80.8%)
#   Đã xử lý: 900/990 câu (90.9%)
# Hoàn thành tách từ cho 990 câu
# 971 câu
# [147/153] (96.1%) Processing: vpbank/bctn_2019_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 918 câu hợp lệ
# Đã lọc bỏ 10 câu quá ngắn
# Đang tách từ cho 918 câu...
#   Đã xử lý: 100/918 câu (10.9%)
#   Đã xử lý: 200/918 câu (21.8%)
#   Đã xử lý: 300/918 câu (32.7%)
#   Đã xử lý: 400/918 câu (43.6%)
#   Đã xử lý: 500/918 câu (54.5%)
#   Đã xử lý: 600/918 câu (65.4%)
#   Đã xử lý: 700/918 câu (76.3%)
#   Đã xử lý: 800/918 câu (87.1%)
#   Đã xử lý: 900/918 câu (98.0%)
# Hoàn thành tách từ cho 918 câu
# 903 câu
# [148/153] (96.7%) Processing: vpbank/bctn_2020_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 1,203 câu hợp lệ
# Đã lọc bỏ 12 câu quá ngắn
# Đang tách từ cho 1,203 câu...
#   Đã xử lý: 100/1203 câu (8.3%)
#   Đã xử lý: 200/1203 câu (16.6%)
#   Đã xử lý: 300/1203 câu (24.9%)
#   Đã xử lý: 400/1203 câu (33.3%)
#   Đã xử lý: 500/1203 câu (41.6%)
#   Đã xử lý: 600/1203 câu (49.9%)
#   Đã xử lý: 700/1203 câu (58.2%)
#   Đã xử lý: 800/1203 câu (66.5%)
#   Đã xử lý: 900/1203 câu (74.8%)
#   Đã xử lý: 1000/1203 câu (83.1%)
#   Đã xử lý: 1100/1203 câu (91.4%)
#   Đã xử lý: 1200/1203 câu (99.8%)
# Hoàn thành tách từ cho 1,203 câu
# 1,160 câu
# [149/153] (97.4%) Processing: vpbank/bctn_2021_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 1,363 câu hợp lệ
# Đã lọc bỏ 12 câu quá ngắn
# Đang tách từ cho 1,363 câu...
#   Đã xử lý: 100/1363 câu (7.3%)
#   Đã xử lý: 200/1363 câu (14.7%)
#   Đã xử lý: 300/1363 câu (22.0%)
#   Đã xử lý: 400/1363 câu (29.3%)
#   Đã xử lý: 500/1363 câu (36.7%)
#   Đã xử lý: 600/1363 câu (44.0%)
#   Đã xử lý: 700/1363 câu (51.4%)
#   Đã xử lý: 800/1363 câu (58.7%)
#   Đã xử lý: 900/1363 câu (66.0%)
#   Đã xử lý: 1000/1363 câu (73.4%)
#   Đã xử lý: 1100/1363 câu (80.7%)
#   Đã xử lý: 1200/1363 câu (88.0%)
#   Đã xử lý: 1300/1363 câu (95.4%)
# Hoàn thành tách từ cho 1,363 câu
# 1,327 câu
# [150/153] (98.0%) Processing: vpbank/bctn_2022_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 1,381 câu hợp lệ
# Đã lọc bỏ 14 câu quá ngắn
# Đang tách từ cho 1,381 câu...
#   Đã xử lý: 100/1381 câu (7.2%)
#   Đã xử lý: 200/1381 câu (14.5%)
#   Đã xử lý: 300/1381 câu (21.7%)
#   Đã xử lý: 400/1381 câu (29.0%)
#   Đã xử lý: 500/1381 câu (36.2%)
#   Đã xử lý: 600/1381 câu (43.4%)
#   Đã xử lý: 700/1381 câu (50.7%)
#   Đã xử lý: 800/1381 câu (57.9%)
#   Đã xử lý: 900/1381 câu (65.2%)
#   Đã xử lý: 1000/1381 câu (72.4%)
#   Đã xử lý: 1100/1381 câu (79.7%)
#   Đã xử lý: 1200/1381 câu (86.9%)
#   Đã xử lý: 1300/1381 câu (94.1%)
# Hoàn thành tách từ cho 1,381 câu
# 1,357 câu
# [151/153] (98.7%) Processing: vpbank/bctn_2023_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 1,981 câu hợp lệ
# Đã lọc bỏ 50 câu quá ngắn
# Đang tách từ cho 1,981 câu...
#   Lỗi tại câu 1: 400: Unable to parse form content
#   Đã xử lý: 100/1981 câu (5.0%)
#   Đã xử lý: 200/1981 câu (10.1%)
#   Đã xử lý: 300/1981 câu (15.1%)
#   Đã xử lý: 400/1981 câu (20.2%)
#   Đã xử lý: 500/1981 câu (25.2%)
#   Đã xử lý: 600/1981 câu (30.3%)
#   Đã xử lý: 700/1981 câu (35.3%)
#   Đã xử lý: 800/1981 câu (40.4%)
#   Đã xử lý: 900/1981 câu (45.4%)
#   Đã xử lý: 1000/1981 câu (50.5%)
#   Đã xử lý: 1100/1981 câu (55.5%)
#   Đã xử lý: 1200/1981 câu (60.6%)
#   Đã xử lý: 1300/1981 câu (65.6%)
#   Đã xử lý: 1400/1981 câu (70.7%)
#   Đã xử lý: 1500/1981 câu (75.7%)
#   Đã xử lý: 1600/1981 câu (80.8%)
#   Đã xử lý: 1700/1981 câu (85.8%)
#   Đã xử lý: 1800/1981 câu (90.9%)
#   Đã xử lý: 1900/1981 câu (95.9%)
# Hoàn thành tách từ cho 1,981 câu
# 1,948 câu
# [152/153] (99.3%) Processing: vpbank/bctn_2024_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 2,018 câu hợp lệ
# Đã lọc bỏ 29 câu quá ngắn
# Đang tách từ cho 2,018 câu...
#   Đã xử lý: 100/2018 câu (5.0%)
#   Đã xử lý: 200/2018 câu (9.9%)
#   Đã xử lý: 300/2018 câu (14.9%)
#   Đã xử lý: 400/2018 câu (19.8%)
#   Đã xử lý: 500/2018 câu (24.8%)
#   Đã xử lý: 600/2018 câu (29.7%)
#   Đã xử lý: 700/2018 câu (34.7%)
#   Đã xử lý: 800/2018 câu (39.6%)
#   Đã xử lý: 900/2018 câu (44.6%)
#   Đã xử lý: 1000/2018 câu (49.6%)
#   Đã xử lý: 1100/2018 câu (54.5%)
#   Đã xử lý: 1200/2018 câu (59.5%)
#   Đã xử lý: 1300/2018 câu (64.4%)
#   Đã xử lý: 1400/2018 câu (69.4%)
#   Đã xử lý: 1500/2018 câu (74.3%)
#   Đã xử lý: 1600/2018 câu (79.3%)
#   Đã xử lý: 1700/2018 câu (84.2%)
#   Đã xử lý: 1800/2018 câu (89.2%)
#   Đã xử lý: 1900/2018 câu (94.2%)
#   Đã xử lý: 2000/2018 câu (99.1%)
# Hoàn thành tách từ cho 2,018 câu
# 1,990 câu
# [153/153] (100.0%) Processing: vpbank/ptbv_2024_raw.txt
# phân đoạn câu bằng underthesea...
# Đã tách thành 1,023 câu hợp lệ
# Đã lọc bỏ 0 câu quá ngắn
# Đang tách từ cho 1,023 câu...
#   Đã xử lý: 100/1023 câu (9.8%)
#   Đã xử lý: 200/1023 câu (19.6%)
#   Đã xử lý: 300/1023 câu (29.3%)
#   Đã xử lý: 400/1023 câu (39.1%)
#   Đã xử lý: 500/1023 câu (48.9%)
#   Đã xử lý: 600/1023 câu (58.7%)
#   Đã xử lý: 700/1023 câu (68.4%)
#   Đã xử lý: 800/1023 câu (78.2%)
#   Đã xử lý: 900/1023 câu (88.0%)
#   Đã xử lý: 1000/1023 câu (97.8%)
# Hoàn thành tách từ cho 1,023 câu
# 999 câu
# Thành công:          144/153 file
# Thất bại:            9/153 file
# ======================================================================

# %% [markdown]
# ### Lưu kết quả

# %%
if df_all_sentences is not None and len(df_all_sentences) > 0:
    output_csv = '../data/all_banks_preprocessed_sentences.csv'
    df_all_sentences.to_csv(output_csv, index=False, encoding='utf-8')
